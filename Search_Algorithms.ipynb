# %% [markdown]
# <a href="https://colab.research.google.com/github/markandrew0501/DS-Final-Project/blob/main/Search_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Breadth-first Search


from collections import deque

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)
print()

# Helper function to find the position of the blank (0)
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if two states are equal
def is_goal(state):
    return state == goal_state

# Generate new states from the current state
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [row[:] for row in state]  # deep copy
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to a tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# BFS Implementation
def bfs(start_state):
    visited = set()
    queue = deque()
    queue.append((start_state, []))  # state and path
    visited.add(state_to_tuple(start_state))

    while queue:
        state, path = queue.popleft()

        if is_goal(state):
            return path + [state]

        for neighbor in get_neighbors(state):
            t_neighbor = state_to_tuple(neighbor)
            if t_neighbor not in visited:
                visited.add(t_neighbor)
                queue.append((neighbor, path + [state]))

    return None  # if no solution found


# Solve the puzzle
solution = bfs(start_state)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")

# %%
#Depth-first Search


from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)
print()

# Helper function to find the position of the blank (0)
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if two states are equal
def is_goal(state):
    return state == goal_state

# Generate new states from the current state
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to a tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# DFS Implementation
def dfs(start_state, max_depth=50):
    visited = set()
    stack = [(start_state, [], 0)]  # state, path, depth

    while stack:
        state, path, depth = stack.pop()

        if is_goal(state):
            return path + [state]

        if depth >= max_depth:
            continue

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(state)):  # reverse to simulate left-to-right exploration
                stack.append((neighbor, path + [state], depth + 1))

    return None  # if no solution found


# Solve the puzzle
solution = dfs(start_state, max_depth=30)  # adjust max_depth as needed

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found within max depth.")

# %%
#Uniform Cost Search

from heapq import heappush, heappop
from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)
print()

# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# UCS Implementation
def ucs(start_state):
    visited = set()
    pq = []
    heappush(pq, (0, start_state, []))  # (cost, state, path)

    while pq:
        cost, state, path = heappop(pq)

        if is_goal(state):
            return path + [state], cost

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                heappush(pq, (cost + 1, neighbor, path + [state]))  # cost per move = 1

    return None, None  # no solution found


# Solve the puzzle
solution, total_cost = ucs(start_state)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves with total cost {total_cost}:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")

# %%
#Depth Limited Search

from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Ask the user for depth limit
depth_limit = int(input("Enter the depth limit: "))

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)

print(f"\nDepth Limit: {depth_limit}\n")

# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Depth-Limited Search (DLS) Implementation
def dls(start_state, limit):
    visited = set()
    stack = [(start_state, [], 0)]  # state, path, depth

    while stack:
        state, path, depth = stack.pop()

        if is_goal(state):
            return path + [state]

        if depth >= limit:
            continue

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(state)):
                stack.append((neighbor, path + [state], depth + 1))

    return None  # no solution within depth limit


# Solve the puzzle
solution = dls(start_state, depth_limit)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print(f"No solution found within depth limit {depth_limit}.")

# %%
#Iterative Deepening Search

from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)


# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Depth-Limited Search (DLS) used in IDS
def dls_ids(state, limit, visited=set()):
    stack = [(state, [], 0)]  # state, path, depth

    while stack:
        current_state, path, depth = stack.pop()

        if is_goal(current_state):
            return path + [current_state]

        if depth >= limit:
            continue

        t_state = state_to_tuple(current_state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(current_state)):
                stack.append((neighbor, path + [current_state], depth + 1))

    return None

# Iterative Deepening Search (IDS)
def ids(start_state, max_depth=50):
    for depth in range(max_depth):
        visited = set()
        result = dls_ids(start_state, depth, visited)
        if result is not None:
            return result
    return None


# Solve the puzzle
solution = ids(start_state, max_depth=100)  # max_depth can be adjusted

# Display the solution
if solution:
    print(f"\nSolution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found within max depth.")

# %%
#Greedy Best-First Search (GBFS)

from heapq import heappush, heappop
from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)


# Helper functions
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

def is_goal(state):
    return state == goal_state

def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Heuristic: Manhattan Distance
def manhattan_distance(state):
    distance = 0
    for i in range(3):
        for j in range(3):
            val = state[i][j]
            if val != 0:
                goal_x, goal_y = divmod(val-1, 3)
                distance += abs(i - goal_x) + abs(j - goal_y)
    return distance

# Greedy Best-First Search
def gbfs(start_state):
    visited = set()
    pq = []
    heappush(pq, (manhattan_distance(start_state), start_state, []))  # (heuristic, state, path)

    counter = 1
    while pq:
        h, state, path = heappop(pq)

        # Show heuristic value of expanded node
        print(f"{counter}. Expanding node with heuristic h(n) = {h}")
        counter += 1
        if is_goal(state):
            return path + [state]

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                h_val = manhattan_distance(neighbor)
                heappush(pq, (h_val, neighbor, path + [state]))

    return None

# Solve the puzzle
solution = gbfs(start_state)

# Display the solution
if solution:
    print(f"\nSolution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")
# Out:
# Enter the start state (3x3, use 0 for blank):
# 4 5 8
# 3 1 0
# 7 6 2
# Enter the goal state (3x3, use 0 for blank):
# 1 2 3
# 7 8 0
# 4 5 6
#
# Start State:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Goal State:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]
# 1. Expanding node with heuristic h(n) = 15
# 2. Expanding node with heuristic h(n) = 14
# 3. Expanding node with heuristic h(n) = 14
# 4. Expanding node with heuristic h(n) = 13
# 5. Expanding node with heuristic h(n) = 14
# 6. Expanding node with heuristic h(n) = 13
# 7. Expanding node with heuristic h(n) = 12
# 8. Expanding node with heuristic h(n) = 11
# 9. Expanding node with heuristic h(n) = 10
# 10. Expanding node with heuristic h(n) = 11
# 11. Expanding node with heuristic h(n) = 11
# 12. Expanding node with heuristic h(n) = 10
# 13. Expanding node with heuristic h(n) = 12
# 14. Expanding node with heuristic h(n) = 12
# 15. Expanding node with heuristic h(n) = 11
# 16. Expanding node with heuristic h(n) = 10
# 17. Expanding node with heuristic h(n) = 11
# 18. Expanding node with heuristic h(n) = 11
# 19. Expanding node with heuristic h(n) = 10
# 20. Expanding node with heuristic h(n) = 10
# 21. Expanding node with heuristic h(n) = 11
# 22. Expanding node with heuristic h(n) = 11
# 23. Expanding node with heuristic h(n) = 10
# 24. Expanding node with heuristic h(n) = 9
# 25. Expanding node with heuristic h(n) = 8
# 26. Expanding node with heuristic h(n) = 9
# 27. Expanding node with heuristic h(n) = 8
# 28. Expanding node with heuristic h(n) = 8
# 29. Expanding node with heuristic h(n) = 8
# 30. Expanding node with heuristic h(n) = 9
# 31. Expanding node with heuristic h(n) = 9
# 32. Expanding node with heuristic h(n) = 9
# 33. Expanding node with heuristic h(n) = 8
# 34. Expanding node with heuristic h(n) = 9
# 35. Expanding node with heuristic h(n) = 8
# 36. Expanding node with heuristic h(n) = 7
# 37. Expanding node with heuristic h(n) = 6
# 38. Expanding node with heuristic h(n) = 7
# 39. Expanding node with heuristic h(n) = 7
# 40. Expanding node with heuristic h(n) = 6
# 41. Expanding node with heuristic h(n) = 8
# 42. Expanding node with heuristic h(n) = 8
# 43. Expanding node with heuristic h(n) = 8
# 44. Expanding node with heuristic h(n) = 8
# 45. Expanding node with heuristic h(n) = 7
# 46. Expanding node with heuristic h(n) = 7
# 47. Expanding node with heuristic h(n) = 6
# 48. Expanding node with heuristic h(n) = 7
# 49. Expanding node with heuristic h(n) = 7
# 50. Expanding node with heuristic h(n) = 6
# 51. Expanding node with heuristic h(n) = 8
# 52. Expanding node with heuristic h(n) = 7
# 53. Expanding node with heuristic h(n) = 6
# 54. Expanding node with heuristic h(n) = 7
# 55. Expanding node with heuristic h(n) = 7
# 56. Expanding node with heuristic h(n) = 7
# 57. Expanding node with heuristic h(n) = 6
# 58. Expanding node with heuristic h(n) = 8
# 59. Expanding node with heuristic h(n) = 7
# 60. Expanding node with heuristic h(n) = 8
# 61. Expanding node with heuristic h(n) = 8
# 62. Expanding node with heuristic h(n) = 7
# 63. Expanding node with heuristic h(n) = 6
# 64. Expanding node with heuristic h(n) = 7
# 65. Expanding node with heuristic h(n) = 7
# 66. Expanding node with heuristic h(n) = 7
# 67. Expanding node with heuristic h(n) = 7
# 68. Expanding node with heuristic h(n) = 6
# 69. Expanding node with heuristic h(n) = 8
# 70. Expanding node with heuristic h(n) = 7
# 71. Expanding node with heuristic h(n) = 7
# 72. Expanding node with heuristic h(n) = 6
# 73. Expanding node with heuristic h(n) = 5
# 74. Expanding node with heuristic h(n) = 4
# 75. Expanding node with heuristic h(n) = 5
# 76. Expanding node with heuristic h(n) = 4
# 77. Expanding node with heuristic h(n) = 5
# 78. Expanding node with heuristic h(n) = 6
# 79. Expanding node with heuristic h(n) = 5
# 80. Expanding node with heuristic h(n) = 4
# 81. Expanding node with heuristic h(n) = 5
# 82. Expanding node with heuristic h(n) = 5
# 83. Expanding node with heuristic h(n) = 5
# 84. Expanding node with heuristic h(n) = 4
# 85. Expanding node with heuristic h(n) = 6
# 86. Expanding node with heuristic h(n) = 6
# 87. Expanding node with heuristic h(n) = 5
# 88. Expanding node with heuristic h(n) = 6
# 89. Expanding node with heuristic h(n) = 6
# 90. Expanding node with heuristic h(n) = 5
# 91. Expanding node with heuristic h(n) = 6
# 92. Expanding node with heuristic h(n) = 5
# 93. Expanding node with heuristic h(n) = 5
# 94. Expanding node with heuristic h(n) = 4
# 95. Expanding node with heuristic h(n) = 5
# 96. Expanding node with heuristic h(n) = 5
# 97. Expanding node with heuristic h(n) = 4
# 98. Expanding node with heuristic h(n) = 6
# 99. Expanding node with heuristic h(n) = 5
# 100. Expanding node with heuristic h(n) = 6
# 101. Expanding node with heuristic h(n) = 6
# 102. Expanding node with heuristic h(n) = 5
# 103. Expanding node with heuristic h(n) = 4
# 104. Expanding node with heuristic h(n) = 5
# 105. Expanding node with heuristic h(n) = 5
# 106. Expanding node with heuristic h(n) = 5
# 107. Expanding node with heuristic h(n) = 4
# 108. Expanding node with heuristic h(n) = 6
# 109. Expanding node with heuristic h(n) = 5
# 110. Expanding node with heuristic h(n) = 6
# 111. Expanding node with heuristic h(n) = 6
# 112. Expanding node with heuristic h(n) = 5
# 113. Expanding node with heuristic h(n) = 6
# 114. Expanding node with heuristic h(n) = 5
# 115. Expanding node with heuristic h(n) = 5
# 116. Expanding node with heuristic h(n) = 4
# 117. Expanding node with heuristic h(n) = 5
# 118. Expanding node with heuristic h(n) = 5
# 119. Expanding node with heuristic h(n) = 4
# 120. Expanding node with heuristic h(n) = 6
# 121. Expanding node with heuristic h(n) = 5
# 122. Expanding node with heuristic h(n) = 6
# 123. Expanding node with heuristic h(n) = 6
# 124. Expanding node with heuristic h(n) = 5
# 125. Expanding node with heuristic h(n) = 5
# 126. Expanding node with heuristic h(n) = 6
# 127. Expanding node with heuristic h(n) = 6
# 128. Expanding node with heuristic h(n) = 5
# 129. Expanding node with heuristic h(n) = 6
# 130. Expanding node with heuristic h(n) = 5
# 131. Expanding node with heuristic h(n) = 6
# 132. Expanding node with heuristic h(n) = 5
# 133. Expanding node with heuristic h(n) = 5
# 134. Expanding node with heuristic h(n) = 4
# 135. Expanding node with heuristic h(n) = 5
# 136. Expanding node with heuristic h(n) = 4
# 137. Expanding node with heuristic h(n) = 5
# 138. Expanding node with heuristic h(n) = 6
# 139. Expanding node with heuristic h(n) = 5
# 140. Expanding node with heuristic h(n) = 6
# 141. Expanding node with heuristic h(n) = 5
# 142. Expanding node with heuristic h(n) = 6
# 143. Expanding node with heuristic h(n) = 5
# 144. Expanding node with heuristic h(n) = 6
# 145. Expanding node with heuristic h(n) = 7
# 146. Expanding node with heuristic h(n) = 6
# 147. Expanding node with heuristic h(n) = 6
# 148. Expanding node with heuristic h(n) = 6
# 149. Expanding node with heuristic h(n) = 7
# 150. Expanding node with heuristic h(n) = 7
# 151. Expanding node with heuristic h(n) = 7
# 152. Expanding node with heuristic h(n) = 6
# 153. Expanding node with heuristic h(n) = 6
# 154. Expanding node with heuristic h(n) = 6
# 155. Expanding node with heuristic h(n) = 7
# 156. Expanding node with heuristic h(n) = 7
# 157. Expanding node with heuristic h(n) = 7
# 158. Expanding node with heuristic h(n) = 6
# 159. Expanding node with heuristic h(n) = 6
# 160. Expanding node with heuristic h(n) = 6
# 161. Expanding node with heuristic h(n) = 7
# 162. Expanding node with heuristic h(n) = 7
# 163. Expanding node with heuristic h(n) = 7
# 164. Expanding node with heuristic h(n) = 6
# 165. Expanding node with heuristic h(n) = 7
# 166. Expanding node with heuristic h(n) = 6
# 167. Expanding node with heuristic h(n) = 6
# 168. Expanding node with heuristic h(n) = 6
# 169. Expanding node with heuristic h(n) = 7
# 170. Expanding node with heuristic h(n) = 7
# 171. Expanding node with heuristic h(n) = 7
# 172. Expanding node with heuristic h(n) = 6
# 173. Expanding node with heuristic h(n) = 7
# 174. Expanding node with heuristic h(n) = 6
# 175. Expanding node with heuristic h(n) = 7
# 176. Expanding node with heuristic h(n) = 6
# 177. Expanding node with heuristic h(n) = 6
# 178. Expanding node with heuristic h(n) = 5
# 179. Expanding node with heuristic h(n) = 4
# 180. Expanding node with heuristic h(n) = 5
# 181. Expanding node with heuristic h(n) = 4
# 182. Expanding node with heuristic h(n) = 4
# 183. Expanding node with heuristic h(n) = 5
# 184. Expanding node with heuristic h(n) = 4
# 185. Expanding node with heuristic h(n) = 4
# 186. Expanding node with heuristic h(n) = 5
# 187. Expanding node with heuristic h(n) = 5
# 188. Expanding node with heuristic h(n) = 5
# 189. Expanding node with heuristic h(n) = 5
# 190. Expanding node with heuristic h(n) = 4
# 191. Expanding node with heuristic h(n) = 6
# 192. Expanding node with heuristic h(n) = 6
# 193. Expanding node with heuristic h(n) = 5
# 194. Expanding node with heuristic h(n) = 6
# 195. Expanding node with heuristic h(n) = 5
# 196. Expanding node with heuristic h(n) = 6
# 197. Expanding node with heuristic h(n) = 5
# 198. Expanding node with heuristic h(n) = 6
# 199. Expanding node with heuristic h(n) = 5
# 200. Expanding node with heuristic h(n) = 6
# 201. Expanding node with heuristic h(n) = 5
# 202. Expanding node with heuristic h(n) = 7
# 203. Expanding node with heuristic h(n) = 6
# 204. Expanding node with heuristic h(n) = 6
# 205. Expanding node with heuristic h(n) = 7
# 206. Expanding node with heuristic h(n) = 7
# 207. Expanding node with heuristic h(n) = 6
# 208. Expanding node with heuristic h(n) = 6
# 209. Expanding node with heuristic h(n) = 7
# 210. Expanding node with heuristic h(n) = 7
# 211. Expanding node with heuristic h(n) = 6
# 212. Expanding node with heuristic h(n) = 7
# 213. Expanding node with heuristic h(n) = 6
# 214. Expanding node with heuristic h(n) = 7
# 215. Expanding node with heuristic h(n) = 6
# 216. Expanding node with heuristic h(n) = 7
# 217. Expanding node with heuristic h(n) = 7
# 218. Expanding node with heuristic h(n) = 6
# 219. Expanding node with heuristic h(n) = 7
# 220. Expanding node with heuristic h(n) = 6
# 221. Expanding node with heuristic h(n) = 7
# 222. Expanding node with heuristic h(n) = 6
# 223. Expanding node with heuristic h(n) = 7
# 224. Expanding node with heuristic h(n) = 6
# 225. Expanding node with heuristic h(n) = 7
# 226. Expanding node with heuristic h(n) = 7
# 227. Expanding node with heuristic h(n) = 6
# 228. Expanding node with heuristic h(n) = 7
# 229. Expanding node with heuristic h(n) = 6
# 230. Expanding node with heuristic h(n) = 7
# 231. Expanding node with heuristic h(n) = 6
# 232. Expanding node with heuristic h(n) = 7
# 233. Expanding node with heuristic h(n) = 6
# 234. Expanding node with heuristic h(n) = 6
# 235. Expanding node with heuristic h(n) = 7
# 236. Expanding node with heuristic h(n) = 7
# 237. Expanding node with heuristic h(n) = 6
# 238. Expanding node with heuristic h(n) = 7
# 239. Expanding node with heuristic h(n) = 6
# 240. Expanding node with heuristic h(n) = 7
# 241. Expanding node with heuristic h(n) = 6
# 242. Expanding node with heuristic h(n) = 5
# 243. Expanding node with heuristic h(n) = 4
# 244. Expanding node with heuristic h(n) = 3
# 245. Expanding node with heuristic h(n) = 2
# 246. Expanding node with heuristic h(n) = 1
# 247. Expanding node with heuristic h(n) = 0
# 248. Expanding node with heuristic h(n) = 1
# 249. Expanding node with heuristic h(n) = 0
# 250. Expanding node with heuristic h(n) = 1
# 251. Expanding node with heuristic h(n) = 2
# 252. Expanding node with heuristic h(n) = 1
# 253. Expanding node with heuristic h(n) = 2
# 254. Expanding node with heuristic h(n) = 1
# 255. Expanding node with heuristic h(n) = 2
# 256. Expanding node with heuristic h(n) = 1
# 257. Expanding node with heuristic h(n) = 2
# 258. Expanding node with heuristic h(n) = 3
# 259. Expanding node with heuristic h(n) = 2
# 260. Expanding node with heuristic h(n) = 3
# 261. Expanding node with heuristic h(n) = 2
# 262. Expanding node with heuristic h(n) = 3
# 263. Expanding node with heuristic h(n) = 2
# 264. Expanding node with heuristic h(n) = 3
# 265. Expanding node with heuristic h(n) = 2
# 266. Expanding node with heuristic h(n) = 3
# 267. Expanding node with heuristic h(n) = 2
# 268. Expanding node with heuristic h(n) = 3
# 269. Expanding node with heuristic h(n) = 3
# 270. Expanding node with heuristic h(n) = 2
# 271. Expanding node with heuristic h(n) = 3
# 272. Expanding node with heuristic h(n) = 2
# 273. Expanding node with heuristic h(n) = 4
# 274. Expanding node with heuristic h(n) = 3
# 275. Expanding node with heuristic h(n) = 4
# 276. Expanding node with heuristic h(n) = 3
# 277. Expanding node with heuristic h(n) = 4
# 278. Expanding node with heuristic h(n) = 3
# 279. Expanding node with heuristic h(n) = 4
# 280. Expanding node with heuristic h(n) = 3
# 281. Expanding node with heuristic h(n) = 4
# 282. Expanding node with heuristic h(n) = 3
# 283. Expanding node with heuristic h(n) = 4
# 284. Expanding node with heuristic h(n) = 4
# 285. Expanding node with heuristic h(n) = 3
# 286. Expanding node with heuristic h(n) = 4
# 287. Expanding node with heuristic h(n) = 3
# 288. Expanding node with heuristic h(n) = 4
# 289. Expanding node with heuristic h(n) = 3
# 290. Expanding node with heuristic h(n) = 4
# 291. Expanding node with heuristic h(n) = 3
# 292. Expanding node with heuristic h(n) = 4
# 293. Expanding node with heuristic h(n) = 3
# 294. Expanding node with heuristic h(n) = 4
# 295. Expanding node with heuristic h(n) = 3
# 296. Expanding node with heuristic h(n) = 4
# 297. Expanding node with heuristic h(n) = 3
# 298. Expanding node with heuristic h(n) = 4
# 299. Expanding node with heuristic h(n) = 3
# 300. Expanding node with heuristic h(n) = 4
# 301. Expanding node with heuristic h(n) = 3
# 302. Expanding node with heuristic h(n) = 4
# 303. Expanding node with heuristic h(n) = 3
# 304. Expanding node with heuristic h(n) = 5
# 305. Expanding node with heuristic h(n) = 4
# 306. Expanding node with heuristic h(n) = 5
# 307. Expanding node with heuristic h(n) = 4
# 308. Expanding node with heuristic h(n) = 5
# 309. Expanding node with heuristic h(n) = 4
# 310. Expanding node with heuristic h(n) = 5
# 311. Expanding node with heuristic h(n) = 4
# 312. Expanding node with heuristic h(n) = 5
# 313. Expanding node with heuristic h(n) = 4
# 314. Expanding node with heuristic h(n) = 5
# 315. Expanding node with heuristic h(n) = 4
# 316. Expanding node with heuristic h(n) = 5
# 317. Expanding node with heuristic h(n) = 4
# 318. Expanding node with heuristic h(n) = 4
# 319. Expanding node with heuristic h(n) = 5
# 320. Expanding node with heuristic h(n) = 4
# 321. Expanding node with heuristic h(n) = 5
# 322. Expanding node with heuristic h(n) = 5
# 323. Expanding node with heuristic h(n) = 4
# 324. Expanding node with heuristic h(n) = 5
# 325. Expanding node with heuristic h(n) = 4
# 326. Expanding node with heuristic h(n) = 4
# 327. Expanding node with heuristic h(n) = 5
# 328. Expanding node with heuristic h(n) = 4
# 329. Expanding node with heuristic h(n) = 5
# 330. Expanding node with heuristic h(n) = 5
# 331. Expanding node with heuristic h(n) = 4
# 332. Expanding node with heuristic h(n) = 4
# 333. Expanding node with heuristic h(n) = 5
# 334. Expanding node with heuristic h(n) = 5
# 335. Expanding node with heuristic h(n) = 4
# 336. Expanding node with heuristic h(n) = 5
# 337. Expanding node with heuristic h(n) = 4
# 338. Expanding node with heuristic h(n) = 5
# 339. Expanding node with heuristic h(n) = 4
# 340. Expanding node with heuristic h(n) = 5
# 341. Expanding node with heuristic h(n) = 4
# 342. Expanding node with heuristic h(n) = 4
# 343. Expanding node with heuristic h(n) = 5
# 344. Expanding node with heuristic h(n) = 5
# 345. Expanding node with heuristic h(n) = 4
# 346. Expanding node with heuristic h(n) = 5
# 347. Expanding node with heuristic h(n) = 4
# 348. Expanding node with heuristic h(n) = 5
# 349. Expanding node with heuristic h(n) = 4
# 350. Expanding node with heuristic h(n) = 5
# 351. Expanding node with heuristic h(n) = 4
# 352. Expanding node with heuristic h(n) = 5
# 353. Expanding node with heuristic h(n) = 5
# 354. Expanding node with heuristic h(n) = 4
# 355. Expanding node with heuristic h(n) = 5
# 356. Expanding node with heuristic h(n) = 4
# 357. Expanding node with heuristic h(n) = 5
# 358. Expanding node with heuristic h(n) = 4
# 359. Expanding node with heuristic h(n) = 6
# 360. Expanding node with heuristic h(n) = 5
# 361. Expanding node with heuristic h(n) = 6
# 362. Expanding node with heuristic h(n) = 5
# 363. Expanding node with heuristic h(n) = 6
# 364. Expanding node with heuristic h(n) = 5
# 365. Expanding node with heuristic h(n) = 6
# 366. Expanding node with heuristic h(n) = 5
# 367. Expanding node with heuristic h(n) = 6
# 368. Expanding node with heuristic h(n) = 5
# 369. Expanding node with heuristic h(n) = 6
# 370. Expanding node with heuristic h(n) = 5
# 371. Expanding node with heuristic h(n) = 6
# 372. Expanding node with heuristic h(n) = 5
# 373. Expanding node with heuristic h(n) = 6
# 374. Expanding node with heuristic h(n) = 5
# 375. Expanding node with heuristic h(n) = 6
# 376. Expanding node with heuristic h(n) = 5
# 377. Expanding node with heuristic h(n) = 5
# 378. Expanding node with heuristic h(n) = 6
# 379. Expanding node with heuristic h(n) = 6
# 380. Expanding node with heuristic h(n) = 5
# 381. Expanding node with heuristic h(n) = 6
# 382. Expanding node with heuristic h(n) = 5
# 383. Expanding node with heuristic h(n) = 4
# 384. Expanding node with heuristic h(n) = 5
# 385. Expanding node with heuristic h(n) = 5
# 386. Expanding node with heuristic h(n) = 4
# 387. Expanding node with heuristic h(n) = 5
# 388. Expanding node with heuristic h(n) = 6
# 389. Expanding node with heuristic h(n) = 5
# 390. Expanding node with heuristic h(n) = 6
# 391. Expanding node with heuristic h(n) = 5
# 392. Expanding node with heuristic h(n) = 5
# 393. Expanding node with heuristic h(n) = 4
# 394. Expanding node with heuristic h(n) = 5
# 395. Expanding node with heuristic h(n) = 5
# 396. Expanding node with heuristic h(n) = 4
# 397. Expanding node with heuristic h(n) = 4
# 398. Expanding node with heuristic h(n) = 4
# 399. Expanding node with heuristic h(n) = 5
# 400. Expanding node with heuristic h(n) = 4
# 401. Expanding node with heuristic h(n) = 5
# 402. Expanding node with heuristic h(n) = 4
# 403. Expanding node with heuristic h(n) = 5
# 404. Expanding node with heuristic h(n) = 4
# 405. Expanding node with heuristic h(n) = 4
# 406. Expanding node with heuristic h(n) = 5
# 407. Expanding node with heuristic h(n) = 4
# 408. Expanding node with heuristic h(n) = 5
# 409. Expanding node with heuristic h(n) = 5
# 410. Expanding node with heuristic h(n) = 4
# 411. Expanding node with heuristic h(n) = 4
# 412. Expanding node with heuristic h(n) = 5
# 413. Expanding node with heuristic h(n) = 5
# 414. Expanding node with heuristic h(n) = 4
# 415. Expanding node with heuristic h(n) = 4
# 416. Expanding node with heuristic h(n) = 5
# 417. Expanding node with heuristic h(n) = 4
# 418. Expanding node with heuristic h(n) = 5
# 419. Expanding node with heuristic h(n) = 5
# 420. Expanding node with heuristic h(n) = 5
# 421. Expanding node with heuristic h(n) = 5
# 422. Expanding node with heuristic h(n) = 4
# 423. Expanding node with heuristic h(n) = 4
# 424. Expanding node with heuristic h(n) = 5
# 425. Expanding node with heuristic h(n) = 5
# 426. Expanding node with heuristic h(n) = 4
# 427. Expanding node with heuristic h(n) = 5
# 428. Expanding node with heuristic h(n) = 4
# 429. Expanding node with heuristic h(n) = 4
# 430. Expanding node with heuristic h(n) = 5
#
# Solution found in 62 moves:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 8]
# [3, 1, 2]
# [7, 6, 0]
#
# Step 2:
# [4, 5, 8]
# [3, 1, 2]
# [7, 0, 6]
#
# Step 3:
# [4, 5, 8]
# [3, 0, 2]
# [7, 1, 6]
#
# Step 4:
# [4, 0, 8]
# [3, 5, 2]
# [7, 1, 6]
#
# Step 5:
# [4, 8, 0]
# [3, 5, 2]
# [7, 1, 6]
#
# Step 6:
# [4, 8, 2]
# [3, 5, 0]
# [7, 1, 6]
#
# Step 7:
# [4, 8, 2]
# [3, 0, 5]
# [7, 1, 6]
#
# Step 8:
# [4, 0, 2]
# [3, 8, 5]
# [7, 1, 6]
#
# Step 9:
# [4, 2, 0]
# [3, 8, 5]
# [7, 1, 6]
#
# Step 10:
# [4, 2, 5]
# [3, 8, 0]
# [7, 1, 6]
#
# Step 11:
# [4, 2, 5]
# [3, 8, 6]
# [7, 1, 0]
#
# Step 12:
# [4, 2, 5]
# [3, 8, 6]
# [7, 0, 1]
#
# Step 13:
# [4, 2, 5]
# [3, 0, 6]
# [7, 8, 1]
#
# Step 14:
# [4, 2, 5]
# [0, 3, 6]
# [7, 8, 1]
#
# Step 15:
# [0, 2, 5]
# [4, 3, 6]
# [7, 8, 1]
#
# Step 16:
# [2, 0, 5]
# [4, 3, 6]
# [7, 8, 1]
#
# Step 17:
# [2, 3, 5]
# [4, 0, 6]
# [7, 8, 1]
#
# Step 18:
# [2, 3, 5]
# [4, 6, 0]
# [7, 8, 1]
#
# Step 19:
# [2, 3, 0]
# [4, 6, 5]
# [7, 8, 1]
#
# Step 20:
# [2, 0, 3]
# [4, 6, 5]
# [7, 8, 1]
#
# Step 21:
# [2, 6, 3]
# [4, 0, 5]
# [7, 8, 1]
#
# Step 22:
# [2, 6, 3]
# [4, 5, 0]
# [7, 8, 1]
#
# Step 23:
# [2, 6, 3]
# [4, 5, 1]
# [7, 8, 0]
#
# Step 24:
# [2, 6, 3]
# [4, 5, 1]
# [7, 0, 8]
#
# Step 25:
# [2, 6, 3]
# [4, 0, 1]
# [7, 5, 8]
#
# Step 26:
# [2, 0, 3]
# [4, 6, 1]
# [7, 5, 8]
#
# Step 27:
# [2, 3, 0]
# [4, 6, 1]
# [7, 5, 8]
#
# Step 28:
# [2, 3, 1]
# [4, 6, 0]
# [7, 5, 8]
#
# Step 29:
# [2, 3, 1]
# [4, 0, 6]
# [7, 5, 8]
#
# Step 30:
# [2, 3, 1]
# [4, 5, 6]
# [7, 0, 8]
#
# Step 31:
# [2, 3, 1]
# [4, 5, 6]
# [7, 8, 0]
#
# Step 32:
# [2, 3, 1]
# [4, 5, 0]
# [7, 8, 6]
#
# Step 33:
# [2, 3, 0]
# [4, 5, 1]
# [7, 8, 6]
#
# Step 34:
# [2, 0, 3]
# [4, 5, 1]
# [7, 8, 6]
#
# Step 35:
# [2, 5, 3]
# [4, 0, 1]
# [7, 8, 6]
#
# Step 36:
# [2, 5, 3]
# [4, 1, 0]
# [7, 8, 6]
#
# Step 37:
# [2, 5, 3]
# [4, 1, 6]
# [7, 8, 0]
#
# Step 38:
# [2, 5, 3]
# [4, 1, 6]
# [7, 0, 8]
#
# Step 39:
# [2, 5, 3]
# [4, 1, 6]
# [0, 7, 8]
#
# Step 40:
# [2, 5, 3]
# [0, 1, 6]
# [4, 7, 8]
#
# Step 41:
# [2, 5, 3]
# [1, 0, 6]
# [4, 7, 8]
#
# Step 42:
# [2, 0, 3]
# [1, 5, 6]
# [4, 7, 8]
#
# Step 43:
# [0, 2, 3]
# [1, 5, 6]
# [4, 7, 8]
#
# Step 44:
# [1, 2, 3]
# [0, 5, 6]
# [4, 7, 8]
#
# Step 45:
# [1, 2, 3]
# [5, 0, 6]
# [4, 7, 8]
#
# Step 46:
# [1, 2, 3]
# [5, 7, 6]
# [4, 0, 8]
#
# Step 47:
# [1, 2, 3]
# [5, 7, 6]
# [4, 8, 0]
#
# Step 48:
# [1, 2, 3]
# [5, 7, 0]
# [4, 8, 6]
#
# Step 49:
# [1, 2, 3]
# [5, 0, 7]
# [4, 8, 6]
#
# Step 50:
# [1, 2, 3]
# [0, 5, 7]
# [4, 8, 6]
#
# Step 51:
# [1, 2, 3]
# [4, 5, 7]
# [0, 8, 6]
#
# Step 52:
# [1, 2, 3]
# [4, 5, 7]
# [8, 0, 6]
#
# Step 53:
# [1, 2, 3]
# [4, 0, 7]
# [8, 5, 6]
#
# Step 54:
# [1, 2, 3]
# [4, 7, 0]
# [8, 5, 6]
#
# Step 55:
# [1, 2, 3]
# [4, 7, 6]
# [8, 5, 0]
#
# Step 56:
# [1, 2, 3]
# [4, 7, 6]
# [8, 0, 5]
#
# Step 57:
# [1, 2, 3]
# [4, 7, 6]
# [0, 8, 5]
#
# Step 58:
# [1, 2, 3]
# [0, 7, 6]
# [4, 8, 5]
#
# Step 59:
# [1, 2, 3]
# [7, 0, 6]
# [4, 8, 5]
#
# Step 60:
# [1, 2, 3]
# [7, 8, 6]
# [4, 0, 5]
#
# Step 61:
# [1, 2, 3]
# [7, 8, 6]
# [4, 5, 0]
#
# Step 62:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]

# %%
#A*


from heapq import heappush, heappop
from copy import deepcopy

# Take user input for start state
print("Enter the start state (3x3, use 0 for blank):")
start_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    start_state.append(row)

# Take user input for goal state
print("Enter the goal state (3x3, use 0 for blank):")
goal_state = []
for _ in range(3):
    row = list(map(int, input().split()))
    goal_state.append(row)

# Show the states back to the user
print("\nStart State:")
for row in start_state:
    print(row)

print("\nGoal State:")
for row in goal_state:
    print(row)


# Helper functions
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j


def is_goal(state):
    return state == goal_state


def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors


def state_to_tuple(state):
    return tuple(tuple(row) for row in state)


# Heuristic: Manhattan Distance
def manhattan_distance(state):
    distance = 0
    for i in range(3):
        for j in range(3):
            val = state[i][j]
            if val != 0:
                goal_x, goal_y = divmod(val - 1, 3)
                distance += abs(i - goal_x) + abs(j - goal_y)
    return distance


# A* Search Implementation with heuristic display
def a_star(start_state):
    visited = set()
    pq = []

    g_cost = 0
    h_cost = manhattan_distance(start_state)
    f_cost = g_cost + h_cost
    heappush(pq, (f_cost, g_cost, start_state, []))  # (f, g, state, path)

    counter = 1
    while pq:
        f, g, state, path = heappop(pq)

        # Calculate h for current state
        h = f - g

        if counter == 10:
          print(f"\n{counter}. Expanding node with g={g}, h={h}, f={f}")

        counter += 1


        if is_goal(state):
            return path + [state], g  # solution and number of moves

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                g_new = g + 1
                h_new = manhattan_distance(neighbor)
                f_new = g_new + h_new
                heappush(pq, (f_new, g_new, neighbor, path + [state]))

    return None, None


# Solve the puzzle
solution, total_moves = a_star(start_state)

# Display the solution
if solution:
    print(f"\nSolution found in {total_moves} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")
