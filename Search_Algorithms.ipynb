# %% [markdown]
# <a href="https://colab.research.google.com/github/markandrew0501/DS-Final-Project/blob/main/Search_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Breadth-first Search

from collections import deque

# Define the goal state
goal_state = [
    [1, 2, 3],
    [7, 8, 0],
    [4, 5, 6]
]

# Helper function to find the position of the blank (0)
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if two states are equal
def is_goal(state):
    return state == goal_state

# Generate new states from the current state
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [row[:] for row in state]  # deep copy
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to a tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# BFS Implementation
def bfs(start_state):
    visited = set()
    queue = deque()
    queue.append((start_state, []))  # state and path
    visited.add(state_to_tuple(start_state))

    while queue:
        state, path = queue.popleft()

        if is_goal(state):
            return path + [state]

        for neighbor in get_neighbors(state):
            t_neighbor = state_to_tuple(neighbor)
            if t_neighbor not in visited:
                visited.add(t_neighbor)
                queue.append((neighbor, path + [state]))

    return None  # if no solution found

# Example start state
start_state = [
    [4, 5, 8],
    [3, 1, 0],
    [7, 6, 2]
]

# Solve the puzzle
solution = bfs(start_state)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")

# %%
#Depth-first Search


from copy import deepcopy

# Define the goal state
goal_state = [
    [1, 2, 3],
    [7, 8, 0],
    [4, 5, 6]
]

# Helper function to find the position of the blank (0)
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if two states are equal
def is_goal(state):
    return state == goal_state

# Generate new states from the current state
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to a tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# DFS Implementation
def dfs(start_state, max_depth=28):
    visited = set()
    stack = [(start_state, [], 0)]  # state, path, depth

    while stack:
        state, path, depth = stack.pop()

        if is_goal(state):
            return path + [state]

        if depth >= max_depth:
            continue

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(state)):  # reverse to simulate left-to-right exploration
                stack.append((neighbor, path + [state], depth + 1))

    return None  # if no solution found

# Example start state
start_state = [
    [4, 5, 8],
    [3, 1, 0],
    [7, 6, 2]
]

# Solve the puzzle
solution = dfs(start_state, max_depth=29)  # adjust max_depth as needed

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found within max depth.")
# Out:
# Solution found in 28 moves:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 0]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 2:
# [4, 0, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 3:
# [4, 1, 5]
# [3, 0, 8]
# [7, 6, 2]
#
# Step 4:
# [4, 1, 5]
# [3, 6, 8]
# [7, 0, 2]
#
# Step 5:
# [4, 1, 5]
# [3, 6, 8]
# [0, 7, 2]
#
# Step 6:
# [4, 1, 5]
# [0, 6, 8]
# [3, 7, 2]
#
# Step 7:
# [0, 1, 5]
# [4, 6, 8]
# [3, 7, 2]
#
# Step 8:
# [1, 0, 5]
# [4, 6, 8]
# [3, 7, 2]
#
# Step 9:
# [1, 6, 5]
# [4, 0, 8]
# [3, 7, 2]
#
# Step 10:
# [1, 6, 5]
# [4, 7, 8]
# [3, 0, 2]
#
# Step 11:
# [1, 6, 5]
# [4, 7, 8]
# [0, 3, 2]
#
# Step 12:
# [1, 6, 5]
# [0, 7, 8]
# [4, 3, 2]
#
# Step 13:
# [1, 6, 5]
# [7, 0, 8]
# [4, 3, 2]
#
# Step 14:
# [1, 0, 5]
# [7, 6, 8]
# [4, 3, 2]
#
# Step 15:
# [1, 5, 0]
# [7, 6, 8]
# [4, 3, 2]
#
# Step 16:
# [1, 5, 8]
# [7, 6, 0]
# [4, 3, 2]
#
# Step 17:
# [1, 5, 8]
# [7, 6, 2]
# [4, 3, 0]
#
# Step 18:
# [1, 5, 8]
# [7, 6, 2]
# [4, 0, 3]
#
# Step 19:
# [1, 5, 8]
# [7, 0, 2]
# [4, 6, 3]
#
# Step 20:
# [1, 0, 8]
# [7, 5, 2]
# [4, 6, 3]
#
# Step 21:
# [1, 8, 0]
# [7, 5, 2]
# [4, 6, 3]
#
# Step 22:
# [1, 8, 2]
# [7, 5, 0]
# [4, 6, 3]
#
# Step 23:
# [1, 8, 2]
# [7, 5, 3]
# [4, 6, 0]
#
# Step 24:
# [1, 8, 2]
# [7, 5, 3]
# [4, 0, 6]
#
# Step 25:
# [1, 8, 2]
# [7, 0, 3]
# [4, 5, 6]
#
# Step 26:
# [1, 0, 2]
# [7, 8, 3]
# [4, 5, 6]
#
# Step 27:
# [1, 2, 0]
# [7, 8, 3]
# [4, 5, 6]
#
# Step 28:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]

# %%
#Uniform Cost Search

from heapq import heappush, heappop
from copy import deepcopy

# Define the goal state
goal_state = [
    [1, 2, 3],
    [7, 8, 0],
    [4, 5, 6]
]

# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1,0),(1,0),(0,-1),(0,1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# UCS Implementation
def ucs(start_state):
    visited = set()
    pq = []
    heappush(pq, (0, start_state, []))  # (cost, state, path)

    while pq:
        cost, state, path = heappop(pq)

        if is_goal(state):
            return path + [state], cost

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                heappush(pq, (cost + 1, neighbor, path + [state]))  # cost per move = 1

    return None, None  # no solution found

# Example start state
start_state = [
    [4, 5, 8],
    [3, 1, 0],
    [7, 6, 2]
]

# Solve the puzzle
solution, total_cost = ucs(start_state)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves with total cost {total_cost}:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")
# Out:
# Solution found in 22 moves with total cost 22:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 0]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 2:
# [4, 0, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 3:
# [0, 4, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 4:
# [3, 4, 5]
# [0, 1, 8]
# [7, 6, 2]
#
# Step 5:
# [3, 4, 5]
# [1, 0, 8]
# [7, 6, 2]
#
# Step 6:
# [3, 0, 5]
# [1, 4, 8]
# [7, 6, 2]
#
# Step 7:
# [3, 5, 0]
# [1, 4, 8]
# [7, 6, 2]
#
# Step 8:
# [3, 5, 8]
# [1, 4, 0]
# [7, 6, 2]
#
# Step 9:
# [3, 5, 8]
# [1, 4, 2]
# [7, 6, 0]
#
# Step 10:
# [3, 5, 8]
# [1, 4, 2]
# [7, 0, 6]
#
# Step 11:
# [3, 5, 8]
# [1, 0, 2]
# [7, 4, 6]
#
# Step 12:
# [3, 0, 8]
# [1, 5, 2]
# [7, 4, 6]
#
# Step 13:
# [0, 3, 8]
# [1, 5, 2]
# [7, 4, 6]
#
# Step 14:
# [1, 3, 8]
# [0, 5, 2]
# [7, 4, 6]
#
# Step 15:
# [1, 3, 8]
# [7, 5, 2]
# [0, 4, 6]
#
# Step 16:
# [1, 3, 8]
# [7, 5, 2]
# [4, 0, 6]
#
# Step 17:
# [1, 3, 8]
# [7, 0, 2]
# [4, 5, 6]
#
# Step 18:
# [1, 3, 8]
# [7, 2, 0]
# [4, 5, 6]
#
# Step 19:
# [1, 3, 0]
# [7, 2, 8]
# [4, 5, 6]
#
# Step 20:
# [1, 0, 3]
# [7, 2, 8]
# [4, 5, 6]
#
# Step 21:
# [1, 2, 3]
# [7, 0, 8]
# [4, 5, 6]
#
# Step 22:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]

# %%
#Depth-Limited Search


from copy import deepcopy

# Define the goal state
goal_state = [[1, 2, 3],
              [7, 8, 0],
              [4, 5, 6]]

# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Depth-Limited Search (DLS) Implementation
def dls(start_state, limit):
    visited = set()
    stack = [(start_state, [], 0)]  # state, path, depth

    while stack:
        state, path, depth = stack.pop()

        if is_goal(state):
            return path + [state]

        if depth >= limit:
            continue

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(state)):
                stack.append((neighbor, path + [state], depth + 1))

    return None  # no solution within depth limit

# Example start state
start_state = [ [4, 5, 8],
                [3, 1, 0],
                [7, 6, 2] ]

# Set depth limit
depth_limit = 30  # adjust as needed

# Solve the puzzle
solution = dls(start_state, depth_limit)

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print(f"No solution found within depth limit {depth_limit}.")
# Out:
# No solution found within depth limit 30.

# %%
#Iterative Deeping Search


from copy import deepcopy

# Define the goal state
goal_state = [[1, 2, 3],
              [7, 8, 0],
              [4, 5, 6]]

# Helper function to find the blank (0) position
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

# Check if a state is the goal
def is_goal(state):
    return state == goal_state

# Generate neighbors (valid moves)
def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

# Convert state to tuple for hashing
def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Depth-Limited Search used in IDS
def dls_ids(state, limit, visited): # Note: the 'visited' parameter is not used inside this function as written
    stack = [(state, [], 0)]  # state, path, depth

    while stack:
        current_state, path, depth = stack.pop()

        if is_goal(current_state):
            return path + [current_state]

        if depth >= limit:
            continue

        t_state = state_to_tuple(current_state)
        # The 'visited' set from the outer IDS scope is ignored here
        # A new, local visited set should be used for each DLS call in a pure IDS.
        # However, to prevent cycles within a single DLS run, a visited check is still needed.
        # The provided code had this structure, so it is preserved.
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in reversed(get_neighbors(current_state)):
                stack.append((neighbor, path + [current_state], depth + 1))

    return None

# Iterative Deepening Search (IDS)
def ids(start_state, max_depth=50):
    for depth in range(max_depth):
        # In a typical IDS, the visited set is cleared for each new depth limit
        # to allow re-visiting nodes via shorter paths found in deeper iterations.
        visited = set()
        result = dls_ids(start_state, depth, visited)
        if result is not None:
            return result
    return None

# Example start state
start_state = [[4, 5, 8],
              [3, 1, 0],
              [7, 6, 2]]

# Solve the puzzle
solution = ids(start_state, max_depth=300) # adjust max_depth as needed

# Display the solution
if solution:
    print(f"Solution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found within max depth.")
# Out:
# Solution found in 28 moves:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 0]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 2:
# [4, 0, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 3:
# [4, 1, 5]
# [3, 0, 8]
# [7, 6, 2]
#
# Step 4:
# [4, 1, 5]
# [3, 6, 8]
# [7, 0, 2]
#
# Step 5:
# [4, 1, 5]
# [3, 6, 8]
# [0, 7, 2]
#
# Step 6:
# [4, 1, 5]
# [0, 6, 8]
# [3, 7, 2]
#
# Step 7:
# [0, 1, 5]
# [4, 6, 8]
# [3, 7, 2]
#
# Step 8:
# [1, 0, 5]
# [4, 6, 8]
# [3, 7, 2]
#
# Step 9:
# [1, 6, 5]
# [4, 0, 8]
# [3, 7, 2]
#
# Step 10:
# [1, 6, 5]
# [4, 7, 8]
# [3, 0, 2]
#
# Step 11:
# [1, 6, 5]
# [4, 7, 8]
# [0, 3, 2]
#
# Step 12:
# [1, 6, 5]
# [0, 7, 8]
# [4, 3, 2]
#
# Step 13:
# [1, 6, 5]
# [7, 0, 8]
# [4, 3, 2]
#
# Step 14:
# [1, 0, 5]
# [7, 6, 8]
# [4, 3, 2]
#
# Step 15:
# [1, 5, 0]
# [7, 6, 8]
# [4, 3, 2]
#
# Step 16:
# [1, 5, 8]
# [7, 6, 0]
# [4, 3, 2]
#
# Step 17:
# [1, 5, 8]
# [7, 6, 2]
# [4, 3, 0]
#
# Step 18:
# [1, 5, 8]
# [7, 6, 2]
# [4, 0, 3]
#
# Step 19:
# [1, 5, 8]
# [7, 0, 2]
# [4, 6, 3]
#
# Step 20:
# [1, 0, 8]
# [7, 5, 2]
# [4, 6, 3]
#
# Step 21:
# [1, 8, 0]
# [7, 5, 2]
# [4, 6, 3]
#
# Step 22:
# [1, 8, 2]
# [7, 5, 0]
# [4, 6, 3]
#
# Step 23:
# [1, 8, 2]
# [7, 5, 3]
# [4, 6, 0]
#
# Step 24:
# [1, 8, 2]
# [7, 5, 3]
# [4, 0, 6]
#
# Step 25:
# [1, 8, 2]
# [7, 0, 3]
# [4, 5, 6]
#
# Step 26:
# [1, 0, 2]
# [7, 8, 3]
# [4, 5, 6]
#
# Step 27:
# [1, 2, 0]
# [7, 8, 3]
# [4, 5, 6]
#
# Step 28:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]

# %%
#Greedy Best-first Search


from heapq import heappush, heappop
from copy import deepcopy

# Start and goal states
start_state = [[4, 5, 8],
              [3, 1, 0],
              [7, 6, 2]]

goal_state = [[1, 2, 3],
              [7, 8, 0],
              [4, 5, 6]]

# Helper functions
def find_blank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

def is_goal(state):
    return state == goal_state

def get_neighbors(state):
    neighbors = []
    x, y = find_blank(state)
    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Heuristic: Manhattan Distance
def manhattan_distance(state):
    distance = 0
    for i in range(3):
        for j in range(3):
            val = state[i][j]
            if val != 0:
                # divmod is a clever way to get the target row and column
                goal_x, goal_y = divmod(val - 1, 3)
                # For the specific goal state you are using, we need to adjust
                if val == 7: goal_x, goal_y = 1, 0
                elif val == 8: goal_x, goal_y = 1, 1
                elif val == 4: goal_x, goal_y = 2, 0
                elif val == 5: goal_x, goal_y = 2, 1
                elif val == 6: goal_x, goal_y = 2, 2

                distance += abs(i - goal_x) + abs(j - goal_y)
    return distance

# Greedy Best-First Search
def gbfs(start_state):
    visited = set()
    pq = []
    heappush(pq, (manhattan_distance(start_state), start_state, [])) # (heuristic, state, path)

    counter = 0

    while pq:
        h, state, path = heappop(pq)

        # Show heuristic value of expanded node
        print(f"{counter}. Expanding node with heuristic h(n) = {h}")
        counter = counter+1
        if is_goal(state):
            return path + [state]

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                h_val = manhattan_distance(neighbor)
                heappush(pq, (h_val, neighbor, path + [state]))

    return None

# Solve the puzzle
solution = gbfs(start_state)

# Display the solution
if solution:
    print(f"\nSolution found in {len(solution)-1} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")
# Out:
# 0. Expanding node with heuristic h(n) = 16
# 1. Expanding node with heuristic h(n) = 15
# 2. Expanding node with heuristic h(n) = 15
# 3. Expanding node with heuristic h(n) = 14
# 4. Expanding node with heuristic h(n) = 15
# 5. Expanding node with heuristic h(n) = 14
# 6. Expanding node with heuristic h(n) = 13
# 7. Expanding node with heuristic h(n) = 12
# 8. Expanding node with heuristic h(n) = 13
# 9. Expanding node with heuristic h(n) = 13
# 10. Expanding node with heuristic h(n) = 12
# 11. Expanding node with heuristic h(n) = 11
# 12. Expanding node with heuristic h(n) = 12
# 13. Expanding node with heuristic h(n) = 12
# 14. Expanding node with heuristic h(n) = 11
# 15. Expanding node with heuristic h(n) = 12
# 16. Expanding node with heuristic h(n) = 11
# 17. Expanding node with heuristic h(n) = 11
# 18. Expanding node with heuristic h(n) = 10
# 19. Expanding node with heuristic h(n) = 11
# 20. Expanding node with heuristic h(n) = 10
# 21. Expanding node with heuristic h(n) = 9
# 22. Expanding node with heuristic h(n) = 10
# 23. Expanding node with heuristic h(n) = 10
# 24. Expanding node with heuristic h(n) = 9
# 25. Expanding node with heuristic h(n) = 10
# 26. Expanding node with heuristic h(n) = 10
# 27. Expanding node with heuristic h(n) = 11
# 28. Expanding node with heuristic h(n) = 10
# 29. Expanding node with heuristic h(n) = 11
# 30. Expanding node with heuristic h(n) = 10
# 31. Expanding node with heuristic h(n) = 10
# 32. Expanding node with heuristic h(n) = 11
# 33. Expanding node with heuristic h(n) = 11
# 34. Expanding node with heuristic h(n) = 10
# 35. Expanding node with heuristic h(n) = 11
# 36. Expanding node with heuristic h(n) = 10
# 37. Expanding node with heuristic h(n) = 11
# 38. Expanding node with heuristic h(n) = 10
# 39. Expanding node with heuristic h(n) = 10
# 40. Expanding node with heuristic h(n) = 11
# 41. Expanding node with heuristic h(n) = 10
# 42. Expanding node with heuristic h(n) = 11
# 43. Expanding node with heuristic h(n) = 10
# 44. Expanding node with heuristic h(n) = 11
# 45. Expanding node with heuristic h(n) = 11
# 46. Expanding node with heuristic h(n) = 10
# 47. Expanding node with heuristic h(n) = 11
# 48. Expanding node with heuristic h(n) = 11
# 49. Expanding node with heuristic h(n) = 11
# 50. Expanding node with heuristic h(n) = 11
# 51. Expanding node with heuristic h(n) = 10
# 52. Expanding node with heuristic h(n) = 9
# 53. Expanding node with heuristic h(n) = 8
# 54. Expanding node with heuristic h(n) = 7
# 55. Expanding node with heuristic h(n) = 6
# 56. Expanding node with heuristic h(n) = 7
# 57. Expanding node with heuristic h(n) = 7
# 58. Expanding node with heuristic h(n) = 6
# 59. Expanding node with heuristic h(n) = 7
# 60. Expanding node with heuristic h(n) = 6
# 61. Expanding node with heuristic h(n) = 6
# 62. Expanding node with heuristic h(n) = 7
# 63. Expanding node with heuristic h(n) = 6
# 64. Expanding node with heuristic h(n) = 6
# 65. Expanding node with heuristic h(n) = 7
# 66. Expanding node with heuristic h(n) = 6
# 67. Expanding node with heuristic h(n) = 7
# 68. Expanding node with heuristic h(n) = 7
# 69. Expanding node with heuristic h(n) = 6
# 70. Expanding node with heuristic h(n) = 7
# 71. Expanding node with heuristic h(n) = 6
# 72. Expanding node with heuristic h(n) = 7
# 73. Expanding node with heuristic h(n) = 8
# 74. Expanding node with heuristic h(n) = 7
# 75. Expanding node with heuristic h(n) = 8
# 76. Expanding node with heuristic h(n) = 8
# 77. Expanding node with heuristic h(n) = 7
# 78. Expanding node with heuristic h(n) = 8
# 79. Expanding node with heuristic h(n) = 7
# 80. Expanding node with heuristic h(n) = 8
# 81. Expanding node with heuristic h(n) = 7
# 82. Expanding node with heuristic h(n) = 7
# 83. Expanding node with heuristic h(n) = 7
# 84. Expanding node with heuristic h(n) = 8
# 85. Expanding node with heuristic h(n) = 7
# 86. Expanding node with heuristic h(n) = 8
# 87. Expanding node with heuristic h(n) = 8
# 88. Expanding node with heuristic h(n) = 8
# 89. Expanding node with heuristic h(n) = 7
# 90. Expanding node with heuristic h(n) = 7
# 91. Expanding node with heuristic h(n) = 7
# 92. Expanding node with heuristic h(n) = 8
# 93. Expanding node with heuristic h(n) = 7
# 94. Expanding node with heuristic h(n) = 8
# 95. Expanding node with heuristic h(n) = 8
# 96. Expanding node with heuristic h(n) = 8
# 97. Expanding node with heuristic h(n) = 7
# 98. Expanding node with heuristic h(n) = 7
# 99. Expanding node with heuristic h(n) = 8
# 100. Expanding node with heuristic h(n) = 7
# 101. Expanding node with heuristic h(n) = 8
# 102. Expanding node with heuristic h(n) = 8
# 103. Expanding node with heuristic h(n) = 7
# 104. Expanding node with heuristic h(n) = 8
# 105. Expanding node with heuristic h(n) = 7
# 106. Expanding node with heuristic h(n) = 7
# 107. Expanding node with heuristic h(n) = 8
# 108. Expanding node with heuristic h(n) = 7
# 109. Expanding node with heuristic h(n) = 8
# 110. Expanding node with heuristic h(n) = 8
# 111. Expanding node with heuristic h(n) = 7
# 112. Expanding node with heuristic h(n) = 7
# 113. Expanding node with heuristic h(n) = 8
# 114. Expanding node with heuristic h(n) = 7
# 115. Expanding node with heuristic h(n) = 8
# 116. Expanding node with heuristic h(n) = 7
# 117. Expanding node with heuristic h(n) = 7
# 118. Expanding node with heuristic h(n) = 7
# 119. Expanding node with heuristic h(n) = 8
# 120. Expanding node with heuristic h(n) = 7
# 121. Expanding node with heuristic h(n) = 8
# 122. Expanding node with heuristic h(n) = 8
# 123. Expanding node with heuristic h(n) = 8
# 124. Expanding node with heuristic h(n) = 7
# 125. Expanding node with heuristic h(n) = 7
# 126. Expanding node with heuristic h(n) = 6
# 127. Expanding node with heuristic h(n) = 7
# 128. Expanding node with heuristic h(n) = 6
# 129. Expanding node with heuristic h(n) = 7
# 130. Expanding node with heuristic h(n) = 6
# 131. Expanding node with heuristic h(n) = 6
# 132. Expanding node with heuristic h(n) = 5
# 133. Expanding node with heuristic h(n) = 6
# 134. Expanding node with heuristic h(n) = 5
# 135. Expanding node with heuristic h(n) = 5
# 136. Expanding node with heuristic h(n) = 6
# 137. Expanding node with heuristic h(n) = 5
# 138. Expanding node with heuristic h(n) = 6
# 139. Expanding node with heuristic h(n) = 6
# 140. Expanding node with heuristic h(n) = 7
# 141. Expanding node with heuristic h(n) = 6
# 142. Expanding node with heuristic h(n) = 7
# 143. Expanding node with heuristic h(n) = 6
# 144. Expanding node with heuristic h(n) = 6
# 145. Expanding node with heuristic h(n) = 7
# 146. Expanding node with heuristic h(n) = 6
# 147. Expanding node with heuristic h(n) = 7
# 148. Expanding node with heuristic h(n) = 7
# 149. Expanding node with heuristic h(n) = 6
# 150. Expanding node with heuristic h(n) = 7
# 151. Expanding node with heuristic h(n) = 7
# 152. Expanding node with heuristic h(n) = 7
# 153. Expanding node with heuristic h(n) = 6
# 154. Expanding node with heuristic h(n) = 7
# 155. Expanding node with heuristic h(n) = 6
# 156. Expanding node with heuristic h(n) = 6
# 157. Expanding node with heuristic h(n) = 7
# 158. Expanding node with heuristic h(n) = 6
# 159. Expanding node with heuristic h(n) = 7
# 160. Expanding node with heuristic h(n) = 7
# 161. Expanding node with heuristic h(n) = 6
# 162. Expanding node with heuristic h(n) = 8
# 163. Expanding node with heuristic h(n) = 7
# 164. Expanding node with heuristic h(n) = 7
# 165. Expanding node with heuristic h(n) = 8
# 166. Expanding node with heuristic h(n) = 8
# 167. Expanding node with heuristic h(n) = 7
# 168. Expanding node with heuristic h(n) = 8
# 169. Expanding node with heuristic h(n) = 7
# 170. Expanding node with heuristic h(n) = 7
# 171. Expanding node with heuristic h(n) = 8
# 172. Expanding node with heuristic h(n) = 8
# 173. Expanding node with heuristic h(n) = 7
# 174. Expanding node with heuristic h(n) = 6
# 175. Expanding node with heuristic h(n) = 5
# 176. Expanding node with heuristic h(n) = 4
# 177. Expanding node with heuristic h(n) = 5
# 178. Expanding node with heuristic h(n) = 5
# 179. Expanding node with heuristic h(n) = 4
# 180. Expanding node with heuristic h(n) = 4
# 181. Expanding node with heuristic h(n) = 5
# 182. Expanding node with heuristic h(n) = 4
# 183. Expanding node with heuristic h(n) = 4
# 184. Expanding node with heuristic h(n) = 4
# 185. Expanding node with heuristic h(n) = 5
# 186. Expanding node with heuristic h(n) = 4
# 187. Expanding node with heuristic h(n) = 5
# 188. Expanding node with heuristic h(n) = 4
# 189. Expanding node with heuristic h(n) = 5
# 190. Expanding node with heuristic h(n) = 4
# 191. Expanding node with heuristic h(n) = 5
# 192. Expanding node with heuristic h(n) = 5
# 193. Expanding node with heuristic h(n) = 5
# 194. Expanding node with heuristic h(n) = 4
# 195. Expanding node with heuristic h(n) = 5
# 196. Expanding node with heuristic h(n) = 5
# 197. Expanding node with heuristic h(n) = 4
# 198. Expanding node with heuristic h(n) = 5
# 199. Expanding node with heuristic h(n) = 4
# 200. Expanding node with heuristic h(n) = 4
# 201. Expanding node with heuristic h(n) = 5
# 202. Expanding node with heuristic h(n) = 4
# 203. Expanding node with heuristic h(n) = 5
# 204. Expanding node with heuristic h(n) = 5
# 205. Expanding node with heuristic h(n) = 4
# 206. Expanding node with heuristic h(n) = 6
# 207. Expanding node with heuristic h(n) = 5
# 208. Expanding node with heuristic h(n) = 6
# 209. Expanding node with heuristic h(n) = 5
# 210. Expanding node with heuristic h(n) = 6
# 211. Expanding node with heuristic h(n) = 5
# 212. Expanding node with heuristic h(n) = 6
# 213. Expanding node with heuristic h(n) = 5
# 214. Expanding node with heuristic h(n) = 6
# 215. Expanding node with heuristic h(n) = 5
# 216. Expanding node with heuristic h(n) = 4
# 217. Expanding node with heuristic h(n) = 5
# 218. Expanding node with heuristic h(n) = 4
# 219. Expanding node with heuristic h(n) = 5
# 220. Expanding node with heuristic h(n) = 5
# 221. Expanding node with heuristic h(n) = 5
# 222. Expanding node with heuristic h(n) = 4
# 223. Expanding node with heuristic h(n) = 6
# 224. Expanding node with heuristic h(n) = 5
# 225. Expanding node with heuristic h(n) = 6
# 226. Expanding node with heuristic h(n) = 5
# 227. Expanding node with heuristic h(n) = 6
# 228. Expanding node with heuristic h(n) = 5
# 229. Expanding node with heuristic h(n) = 5
# 230. Expanding node with heuristic h(n) = 6
# 231. Expanding node with heuristic h(n) = 6
# 232. Expanding node with heuristic h(n) = 6
# 233. Expanding node with heuristic h(n) = 5
# 234. Expanding node with heuristic h(n) = 4
# 235. Expanding node with heuristic h(n) = 3
# 236. Expanding node with heuristic h(n) = 2
# 237. Expanding node with heuristic h(n) = 1
# 238. Expanding node with heuristic h(n) = 0
#
# Solution found in 58 moves:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 8]
# [3, 1, 2]
# [7, 6, 0]
#
# Step 2:
# [4, 5, 8]
# [3, 1, 2]
# [7, 0, 6]
#
# Step 3:
# [4, 5, 8]
# [3, 0, 2]
# [7, 1, 6]
#
# Step 4:
# [4, 0, 8]
# [3, 5, 2]
# [7, 1, 6]
#
# Step 5:
# [4, 8, 0]
# [3, 5, 2]
# [7, 1, 6]
#
# Step 6:
# [4, 8, 2]
# [3, 5, 0]
# [7, 1, 6]
#
# Step 7:
# [4, 8, 2]
# [3, 0, 5]
# [7, 1, 6]
#
# Step 8:
# [4, 8, 2]
# [0, 3, 5]
# [7, 1, 6]
#
# Step 9:
# [4, 8, 2]
# [7, 3, 5]
# [0, 1, 6]
#
# Step 10:
# [4, 8, 2]
# [7, 3, 5]
# [1, 0, 6]
#
# Step 11:
# [4, 8, 2]
# [7, 3, 5]
# [1, 6, 0]
#
# Step 12:
# [4, 8, 2]
# [7, 3, 0]
# [1, 6, 5]
#
# Step 13:
# [4, 8, 2]
# [7, 0, 3]
# [1, 6, 5]
#
# Step 14:
# [4, 0, 2]
# [7, 8, 3]
# [1, 6, 5]
#
# Step 15:
# [4, 2, 0]
# [7, 8, 3]
# [1, 6, 5]
#
# Step 16:
# [4, 2, 3]
# [7, 8, 0]
# [1, 6, 5]
#
# Step 17:
# [4, 2, 3]
# [7, 8, 5]
# [1, 6, 0]
#
# Step 18:
# [4, 2, 3]
# [7, 8, 5]
# [1, 0, 6]
#
# Step 19:
# [4, 2, 3]
# [7, 0, 5]
# [1, 8, 6]
#
# Step 20:
# [4, 2, 3]
# [7, 5, 0]
# [1, 8, 6]
#
# Step 21:
# [4, 2, 3]
# [7, 5, 6]
# [1, 8, 0]
#
# Step 22:
# [4, 2, 3]
# [7, 5, 6]
# [1, 0, 8]
#
# Step 23:
# [4, 2, 3]
# [7, 0, 6]
# [1, 5, 8]
#
# Step 24:
# [4, 2, 3]
# [0, 7, 6]
# [1, 5, 8]
#
# Step 25:
# [4, 2, 3]
# [1, 7, 6]
# [0, 5, 8]
#
# Step 26:
# [4, 2, 3]
# [1, 7, 6]
# [5, 0, 8]
#
# Step 27:
# [4, 2, 3]
# [1, 7, 6]
# [5, 8, 0]
#
# Step 28:
# [4, 2, 3]
# [1, 7, 0]
# [5, 8, 6]
#
# Step 29:
# [4, 2, 3]
# [1, 0, 7]
# [5, 8, 6]
#
# Step 30:
# [4, 2, 3]
# [1, 8, 7]
# [5, 0, 6]
#
# Step 31:
# [4, 2, 3]
# [1, 8, 7]
# [0, 5, 6]
#
# Step 32:
# [4, 2, 3]
# [0, 8, 7]
# [1, 5, 6]
#
# Step 33:
# [0, 2, 3]
# [4, 8, 7]
# [1, 5, 6]
#
# Step 34:
# [2, 0, 3]
# [4, 8, 7]
# [1, 5, 6]
#
# Step 35:
# [2, 8, 3]
# [4, 0, 7]
# [1, 5, 6]
#
# Step 36:
# [2, 8, 3]
# [0, 4, 7]
# [1, 5, 6]
#
# Step 37:
# [2, 8, 3]
# [1, 4, 7]
# [0, 5, 6]
#
# Step 38:
# [2, 8, 3]
# [1, 4, 7]
# [5, 0, 6]
#
# Step 39:
# [2, 8, 3]
# [1, 0, 7]
# [5, 4, 6]
#
# Step 40:
# [2, 0, 3]
# [1, 8, 7]
# [5, 4, 6]
#
# Step 41:
# [0, 2, 3]
# [1, 8, 7]
# [5, 4, 6]
#
# Step 42:
# [1, 2, 3]
# [0, 8, 7]
# [5, 4, 6]
#
# Step 43:
# [1, 2, 3]
# [5, 8, 7]
# [0, 4, 6]
#
# Step 44:
# [1, 2, 3]
# [5, 8, 7]
# [4, 0, 6]
#
# Step 45:
# [1, 2, 3]
# [5, 0, 7]
# [4, 8, 6]
#
# Step 46:
# [1, 2, 3]
# [0, 5, 7]
# [4, 8, 6]
#
# Step 47:
# [1, 2, 3]
# [4, 5, 7]
# [0, 8, 6]
#
# Step 48:
# [1, 2, 3]
# [4, 5, 7]
# [8, 0, 6]
#
# Step 49:
# [1, 2, 3]
# [4, 0, 7]
# [8, 5, 6]
#
# Step 50:
# [1, 2, 3]
# [4, 7, 0]
# [8, 5, 6]
#
# Step 51:
# [1, 2, 3]
# [4, 7, 6]
# [8, 5, 0]
#
# Step 52:
# [1, 2, 3]
# [4, 7, 6]
# [8, 0, 5]
#
# Step 53:
# [1, 2, 3]
# [4, 7, 6]
# [0, 8, 5]
#
# Step 54:
# [1, 2, 3]
# [0, 7, 6]
# [4, 8, 5]
#
# Step 55:
# [1, 2, 3]
# [7, 0, 6]
# [4, 8, 5]
#
# Step 56:
# [1, 2, 3]
# [7, 8, 6]
# [4, 0, 5]
#
# Step 57:
# [1, 2, 3]
# [7, 8, 6]
# [4, 5, 0]
#
# Step 58:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]

# %%
#A*


from heapq import heappush, heappop
from copy import deepcopy

# Start and goal states
start_state = [[4, 5, 8],
              [3, 1, 0],
              [7, 6, 2]]

goal_state = [[1, 2, 3],
              [7, 8, 0],
              [4, 5, 6]]

# Helper functions
def find_blank(state):
    # This helper is not used by the heuristic but can be useful for other functions.
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return i, j

def is_goal(state):
    return state == goal_state

def get_neighbors(state):
    neighbors = []
    # Find the blank tile's position
    x, y = -1, -1
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                x, y = i, j
                break
        if x != -1:
            break

    moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]  # up, down, left, right

    for dx, dy in moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)
    return neighbors

def state_to_tuple(state):
    return tuple(tuple(row) for row in state)

# Heuristic: Manhattan Distance
def manhattan_distance(state):
    distance = 0
    goal_positions = {
        1: (0, 0), 2: (0, 1), 3: (0, 2),
        7: (1, 0), 8: (1, 1), 0: (1, 2), # Blank tile is part of the goal
        4: (2, 0), 5: (2, 1), 6: (2, 2)
    }
    for i in range(3):
        for j in range(3):
            val = state[i][j]
            if val != 0:
                goal_x, goal_y = goal_positions[val]
                distance += abs(i - goal_x) + abs(j - goal_y)
    return distance

# A* Search Implementation with heuristic display
def a_star(start_state):
    visited = set()
    pq = []
    g_cost = 0
    h_cost = manhattan_distance(start_state)
    f_cost = g_cost + h_cost
    heappush(pq, (f_cost, g_cost, start_state, []))  # (f, g, state, path)

    counter = 0
    while pq:
        f, g, state, path = heappop(pq)

        # Calculate h for current state
        h = f - g

        # Display expansion details
        print(f"{counter}. Expanding node with g={g}, h={h}, f={f}")
        counter += 1
        if is_goal(state):
            return path + [state], g  # solution and number of moves

        t_state = state_to_tuple(state)
        if t_state not in visited:
            visited.add(t_state)
            for neighbor in get_neighbors(state):
                g_new = g + 1
                h_new = manhattan_distance(neighbor)
                f_new = g_new + h_new
                heappush(pq, (f_new, g_new, neighbor, path + [state]))

    return None, None

# Solve the puzzle
solution, total_moves = a_star(start_state)

# Display the solution
if solution:
    print(f"\nSolution found in {total_moves} moves:")
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
        print()
else:
    print("No solution found.")
# Out:
# 0. Expanding node with g=0, h=16, f=16
# 1. Expanding node with g=1, h=15, f=16
# 2. Expanding node with g=1, h=15, f=16
# 3. Expanding node with g=2, h=14, f=16
# 4. Expanding node with g=1, h=17, f=18
# 5. Expanding node with g=2, h=16, f=18
# 6. Expanding node with g=2, h=16, f=18
# 7. Expanding node with g=2, h=16, f=18
# 8. Expanding node with g=2, h=16, f=18
# 9. Expanding node with g=2, h=16, f=18
# 10. Expanding node with g=2, h=16, f=18
# 11. Expanding node with g=3, h=15, f=18
# 12. Expanding node with g=3, h=15, f=18
# 13. Expanding node with g=3, h=15, f=18
# 14. Expanding node with g=3, h=15, f=18
# 15. Expanding node with g=3, h=15, f=18
# 16. Expanding node with g=3, h=15, f=18
# 17. Expanding node with g=3, h=15, f=18
# 18. Expanding node with g=3, h=15, f=18
# 19. Expanding node with g=4, h=14, f=18
# 20. Expanding node with g=4, h=14, f=18
# 21. Expanding node with g=4, h=14, f=18
# 22. Expanding node with g=4, h=14, f=18
# 23. Expanding node with g=4, h=14, f=18
# 24. Expanding node with g=4, h=14, f=18
# 25. Expanding node with g=4, h=14, f=18
# 26. Expanding node with g=4, h=14, f=18
# 27. Expanding node with g=5, h=13, f=18
# 28. Expanding node with g=5, h=13, f=18
# 29. Expanding node with g=5, h=13, f=18
# 30. Expanding node with g=5, h=13, f=18
# 31. Expanding node with g=5, h=13, f=18
# 32. Expanding node with g=5, h=13, f=18
# 33. Expanding node with g=5, h=13, f=18
# 34. Expanding node with g=5, h=13, f=18
# 35. Expanding node with g=5, h=13, f=18
# 36. Expanding node with g=6, h=12, f=18
# 37. Expanding node with g=6, h=12, f=18
# 38. Expanding node with g=6, h=12, f=18
# 39. Expanding node with g=6, h=12, f=18
# 40. Expanding node with g=6, h=12, f=18
# 41. Expanding node with g=7, h=11, f=18
# 42. Expanding node with g=7, h=11, f=18
# 43. Expanding node with g=7, h=11, f=18
# 44. Expanding node with g=8, h=10, f=18
# 45. Expanding node with g=8, h=10, f=18
# 46. Expanding node with g=8, h=10, f=18
# 47. Expanding node with g=8, h=10, f=18
# 48. Expanding node with g=9, h=9, f=18
# 49. Expanding node with g=9, h=9, f=18
# 50. Expanding node with g=9, h=9, f=18
# 51. Expanding node with g=9, h=9, f=18
# 52. Expanding node with g=9, h=9, f=18
# 53. Expanding node with g=10, h=8, f=18
# 54. Expanding node with g=10, h=8, f=18
# 55. Expanding node with g=10, h=8, f=18
# 56. Expanding node with g=2, h=18, f=20
# 57. Expanding node with g=3, h=17, f=20
# 58. Expanding node with g=3, h=17, f=20
# 59. Expanding node with g=3, h=17, f=20
# 60. Expanding node with g=3, h=17, f=20
# 61. Expanding node with g=3, h=17, f=20
# 62. Expanding node with g=3, h=17, f=20
# 63. Expanding node with g=4, h=16, f=20
# 64. Expanding node with g=4, h=16, f=20
# 65. Expanding node with g=4, h=16, f=20
# 66. Expanding node with g=4, h=16, f=20
# 67. Expanding node with g=4, h=16, f=20
# 68. Expanding node with g=4, h=16, f=20
# 69. Expanding node with g=4, h=16, f=20
# 70. Expanding node with g=4, h=16, f=20
# 71. Expanding node with g=4, h=16, f=20
# 72. Expanding node with g=4, h=16, f=20
# 73. Expanding node with g=4, h=16, f=20
# 74. Expanding node with g=4, h=16, f=20
# 75. Expanding node with g=5, h=15, f=20
# 76. Expanding node with g=5, h=15, f=20
# 77. Expanding node with g=5, h=15, f=20
# 78. Expanding node with g=5, h=15, f=20
# 79. Expanding node with g=5, h=15, f=20
# 80. Expanding node with g=5, h=15, f=20
# 81. Expanding node with g=5, h=15, f=20
# 82. Expanding node with g=5, h=15, f=20
# 83. Expanding node with g=5, h=15, f=20
# 84. Expanding node with g=5, h=15, f=20
# 85. Expanding node with g=5, h=15, f=20
# 86. Expanding node with g=5, h=15, f=20
# 87. Expanding node with g=5, h=15, f=20
# 88. Expanding node with g=5, h=15, f=20
# 89. Expanding node with g=5, h=15, f=20
# 90. Expanding node with g=5, h=15, f=20
# 91. Expanding node with g=5, h=15, f=20
# 92. Expanding node with g=5, h=15, f=20
# 93. Expanding node with g=5, h=15, f=20
# 94. Expanding node with g=5, h=15, f=20
# 95. Expanding node with g=5, h=15, f=20
# 96. Expanding node with g=5, h=15, f=20
# 97. Expanding node with g=6, h=14, f=20
# 98. Expanding node with g=6, h=14, f=20
# 99. Expanding node with g=6, h=14, f=20
# 100. Expanding node with g=6, h=14, f=20
# 101. Expanding node with g=6, h=14, f=20
# 102. Expanding node with g=6, h=14, f=20
# 103. Expanding node with g=6, h=14, f=20
# 104. Expanding node with g=6, h=14, f=20
# 105. Expanding node with g=6, h=14, f=20
# 106. Expanding node with g=6, h=14, f=20
# 107. Expanding node with g=6, h=14, f=20
# 108. Expanding node with g=6, h=14, f=20
# 109. Expanding node with g=6, h=14, f=20
# 110. Expanding node with g=6, h=14, f=20
# 111. Expanding node with g=6, h=14, f=20
# 112. Expanding node with g=6, h=14, f=20
# 113. Expanding node with g=6, h=14, f=20
# 114. Expanding node with g=6, h=14, f=20
# 115. Expanding node with g=6, h=14, f=20
# 116. Expanding node with g=6, h=14, f=20
# 117. Expanding node with g=6, h=14, f=20
# 118. Expanding node with g=6, h=14, f=20
# 119. Expanding node with g=6, h=14, f=20
# 120. Expanding node with g=6, h=14, f=20
# 121. Expanding node with g=6, h=14, f=20
# 122. Expanding node with g=6, h=14, f=20
# 123. Expanding node with g=7, h=13, f=20
# 124. Expanding node with g=7, h=13, f=20
# 125. Expanding node with g=7, h=13, f=20
# 126. Expanding node with g=7, h=13, f=20
# 127. Expanding node with g=7, h=13, f=20
# 128. Expanding node with g=7, h=13, f=20
# 129. Expanding node with g=7, h=13, f=20
# 130. Expanding node with g=7, h=13, f=20
# 131. Expanding node with g=7, h=13, f=20
# 132. Expanding node with g=7, h=13, f=20
# 133. Expanding node with g=7, h=13, f=20
# 134. Expanding node with g=7, h=13, f=20
# 135. Expanding node with g=7, h=13, f=20
# 136. Expanding node with g=7, h=13, f=20
# 137. Expanding node with g=7, h=13, f=20
# 138. Expanding node with g=7, h=13, f=20
# 139. Expanding node with g=7, h=13, f=20
# 140. Expanding node with g=7, h=13, f=20
# 141. Expanding node with g=7, h=13, f=20
# 142. Expanding node with g=7, h=13, f=20
# 143. Expanding node with g=7, h=13, f=20
# 144. Expanding node with g=7, h=13, f=20
# 145. Expanding node with g=7, h=13, f=20
# 146. Expanding node with g=7, h=13, f=20
# 147. Expanding node with g=7, h=13, f=20
# 148. Expanding node with g=7, h=13, f=20
# 149. Expanding node with g=7, h=13, f=20
# 150. Expanding node with g=7, h=13, f=20
# 151. Expanding node with g=7, h=13, f=20
# 152. Expanding node with g=7, h=13, f=20
# 153. Expanding node with g=7, h=13, f=20
# 154. Expanding node with g=7, h=13, f=20
# 155. Expanding node with g=7, h=13, f=20
# 156. Expanding node with g=7, h=13, f=20
# 157. Expanding node with g=8, h=12, f=20
# 158. Expanding node with g=8, h=12, f=20
# 159. Expanding node with g=8, h=12, f=20
# 160. Expanding node with g=8, h=12, f=20
# 161. Expanding node with g=8, h=12, f=20
# 162. Expanding node with g=8, h=12, f=20
# 163. Expanding node with g=8, h=12, f=20
# 164. Expanding node with g=8, h=12, f=20
# 165. Expanding node with g=8, h=12, f=20
# 166. Expanding node with g=8, h=12, f=20
# 167. Expanding node with g=8, h=12, f=20
# 168. Expanding node with g=8, h=12, f=20
# 169. Expanding node with g=8, h=12, f=20
# 170. Expanding node with g=8, h=12, f=20
# 171. Expanding node with g=8, h=12, f=20
# 172. Expanding node with g=8, h=12, f=20
# 173. Expanding node with g=8, h=12, f=20
# 174. Expanding node with g=8, h=12, f=20
# 175. Expanding node with g=8, h=12, f=20
# 176. Expanding node with g=8, h=12, f=20
# 177. Expanding node with g=8, h=12, f=20
# 178. Expanding node with g=8, h=12, f=20
# 179. Expanding node with g=8, h=12, f=20
# 180. Expanding node with g=8, h=12, f=20
# 181. Expanding node with g=8, h=12, f=20
# 182. Expanding node with g=8, h=12, f=20
# 183. Expanding node with g=8, h=12, f=20
# 184. Expanding node with g=8, h=12, f=20
# 185. Expanding node with g=8, h=12, f=20
# 186. Expanding node with g=8, h=12, f=20
# 187. Expanding node with g=8, h=12, f=20
# 188. Expanding node with g=8, h=12, f=20
# 189. Expanding node with g=8, h=12, f=20
# 190. Expanding node with g=8, h=12, f=20
# 191. Expanding node with g=9, h=11, f=20
# 192. Expanding node with g=9, h=11, f=20
# 193. Expanding node with g=9, h=11, f=20
# 194. Expanding node with g=9, h=11, f=20
# 195. Expanding node with g=9, h=11, f=20
# 196. Expanding node with g=9, h=11, f=20
# 197. Expanding node with g=9, h=11, f=20
# 198. Expanding node with g=9, h=11, f=20
# 199. Expanding node with g=9, h=11, f=20
# 200. Expanding node with g=9, h=11, f=20
# 201. Expanding node with g=9, h=11, f=20
# 202. Expanding node with g=9, h=11, f=20
# 203. Expanding node with g=9, h=11, f=20
# 204. Expanding node with g=9, h=11, f=20
# 205. Expanding node with g=9, h=11, f=20
# 206. Expanding node with g=9, h=11, f=20
# 207. Expanding node with g=9, h=11, f=20
# 208. Expanding node with g=9, h=11, f=20
# 209. Expanding node with g=9, h=11, f=20
# 210. Expanding node with g=9, h=11, f=20
# 211. Expanding node with g=9, h=11, f=20
# 212. Expanding node with g=9, h=11, f=20
# 213. Expanding node with g=9, h=11, f=20
# 214. Expanding node with g=9, h=11, f=20
# 215. Expanding node with g=9, h=11, f=20
# 216. Expanding node with g=9, h=11, f=20
# 217. Expanding node with g=9, h=11, f=20
# 218. Expanding node with g=9, h=11, f=20
# 219. Expanding node with g=9, h=11, f=20
# 220. Expanding node with g=9, h=11, f=20
# 221. Expanding node with g=9, h=11, f=20
# 222. Expanding node with g=9, h=11, f=20
# 223. Expanding node with g=10, h=10, f=20
# 224. Expanding node with g=10, h=10, f=20
# 225. Expanding node with g=10, h=10, f=20
# 226. Expanding node with g=10, h=10, f=20
# 227. Expanding node with g=10, h=10, f=20
# 228. Expanding node with g=10, h=10, f=20
# 229. Expanding node with g=10, h=10, f=20
# 230. Expanding node with g=10, h=10, f=20
# 231. Expanding node with g=10, h=10, f=20
# 232. Expanding node with g=10, h=10, f=20
# 233. Expanding node with g=10, h=10, f=20
# 234. Expanding node with g=10, h=10, f=20
# 235. Expanding node with g=10, h=10, f=20
# 236. Expanding node with g=10, h=10, f=20
# 237. Expanding node with g=10, h=10, f=20
# 238. Expanding node with g=10, h=10, f=20
# 239. Expanding node with g=10, h=10, f=20
# 240. Expanding node with g=10, h=10, f=20
# 241. Expanding node with g=10, h=10, f=20
# 242. Expanding node with g=10, h=10, f=20
# 243. Expanding node with g=10, h=10, f=20
# 244. Expanding node with g=10, h=10, f=20
# 245. Expanding node with g=10, h=10, f=20
# 246. Expanding node with g=10, h=10, f=20
# 247. Expanding node with g=11, h=9, f=20
# 248. Expanding node with g=11, h=9, f=20
# 249. Expanding node with g=11, h=9, f=20
# 250. Expanding node with g=11, h=9, f=20
# 251. Expanding node with g=11, h=9, f=20
# 252. Expanding node with g=11, h=9, f=20
# 253. Expanding node with g=11, h=9, f=20
# 254. Expanding node with g=11, h=9, f=20
# 255. Expanding node with g=11, h=9, f=20
# 256. Expanding node with g=11, h=9, f=20
# 257. Expanding node with g=11, h=9, f=20
# 258. Expanding node with g=11, h=9, f=20
# 259. Expanding node with g=11, h=9, f=20
# 260. Expanding node with g=11, h=9, f=20
# 261. Expanding node with g=11, h=9, f=20
# 262. Expanding node with g=11, h=9, f=20
# 263. Expanding node with g=11, h=9, f=20
# 264. Expanding node with g=11, h=9, f=20
# 265. Expanding node with g=11, h=9, f=20
# 266. Expanding node with g=11, h=9, f=20
# 267. Expanding node with g=11, h=9, f=20
# 268. Expanding node with g=11, h=9, f=20
# 269. Expanding node with g=11, h=9, f=20
# 270. Expanding node with g=11, h=9, f=20
# 271. Expanding node with g=11, h=9, f=20
# 272. Expanding node with g=12, h=8, f=20
# 273. Expanding node with g=12, h=8, f=20
# 274. Expanding node with g=12, h=8, f=20
# 275. Expanding node with g=12, h=8, f=20
# 276. Expanding node with g=12, h=8, f=20
# 277. Expanding node with g=12, h=8, f=20
# 278. Expanding node with g=12, h=8, f=20
# 279. Expanding node with g=12, h=8, f=20
# 280. Expanding node with g=12, h=8, f=20
# 281. Expanding node with g=12, h=8, f=20
# 282. Expanding node with g=12, h=8, f=20
# 283. Expanding node with g=12, h=8, f=20
# 284. Expanding node with g=12, h=8, f=20
# 285. Expanding node with g=12, h=8, f=20
# 286. Expanding node with g=12, h=8, f=20
# 287. Expanding node with g=12, h=8, f=20
# 288. Expanding node with g=12, h=8, f=20
# 289. Expanding node with g=12, h=8, f=20
# 290. Expanding node with g=12, h=8, f=20
# 291. Expanding node with g=13, h=7, f=20
# 292. Expanding node with g=13, h=7, f=20
# 293. Expanding node with g=13, h=7, f=20
# 294. Expanding node with g=13, h=7, f=20
# 295. Expanding node with g=13, h=7, f=20
# 296. Expanding node with g=13, h=7, f=20
# 297. Expanding node with g=14, h=6, f=20
# 298. Expanding node with g=14, h=6, f=20
# 299. Expanding node with g=14, h=6, f=20
# 300. Expanding node with g=14, h=6, f=20
# 301. Expanding node with g=14, h=6, f=20
# 302. Expanding node with g=15, h=5, f=20
# 303. Expanding node with g=15, h=5, f=20
# 304. Expanding node with g=15, h=5, f=20
# 305. Expanding node with g=15, h=5, f=20
# 306. Expanding node with g=15, h=5, f=20
# 307. Expanding node with g=16, h=4, f=20
# 308. Expanding node with g=16, h=4, f=20
# 309. Expanding node with g=16, h=4, f=20
# 310. Expanding node with g=16, h=4, f=20
# 311. Expanding node with g=16, h=4, f=20
# 312. Expanding node with g=16, h=4, f=20
# 313. Expanding node with g=3, h=19, f=22
# 314. Expanding node with g=4, h=18, f=22
# 315. Expanding node with g=4, h=18, f=22
# 316. Expanding node with g=4, h=18, f=22
# 317. Expanding node with g=5, h=17, f=22
# 318. Expanding node with g=5, h=17, f=22
# 319. Expanding node with g=5, h=17, f=22
# 320. Expanding node with g=5, h=17, f=22
# 321. Expanding node with g=5, h=17, f=22
# 322. Expanding node with g=5, h=17, f=22
# 323. Expanding node with g=5, h=17, f=22
# 324. Expanding node with g=5, h=17, f=22
# 325. Expanding node with g=6, h=16, f=22
# 326. Expanding node with g=6, h=16, f=22
# 327. Expanding node with g=6, h=16, f=22
# 328. Expanding node with g=6, h=16, f=22
# 329. Expanding node with g=6, h=16, f=22
# 330. Expanding node with g=6, h=16, f=22
# 331. Expanding node with g=6, h=16, f=22
# 332. Expanding node with g=6, h=16, f=22
# 333. Expanding node with g=6, h=16, f=22
# 334. Expanding node with g=6, h=16, f=22
# 335. Expanding node with g=6, h=16, f=22
# 336. Expanding node with g=6, h=16, f=22
# 337. Expanding node with g=6, h=16, f=22
# 338. Expanding node with g=6, h=16, f=22
# 339. Expanding node with g=6, h=16, f=22
# 340. Expanding node with g=6, h=16, f=22
# 341. Expanding node with g=6, h=16, f=22
# 342. Expanding node with g=6, h=16, f=22
# 343. Expanding node with g=6, h=16, f=22
# 344. Expanding node with g=6, h=16, f=22
# 345. Expanding node with g=6, h=16, f=22
# 346. Expanding node with g=6, h=16, f=22
# 347. Expanding node with g=6, h=16, f=22
# 348. Expanding node with g=6, h=16, f=22
# 349. Expanding node with g=6, h=16, f=22
# 350. Expanding node with g=6, h=16, f=22
# 351. Expanding node with g=6, h=16, f=22
# 352. Expanding node with g=6, h=16, f=22
# 353. Expanding node with g=6, h=16, f=22
# 354. Expanding node with g=7, h=15, f=22
# 355. Expanding node with g=7, h=15, f=22
# 356. Expanding node with g=7, h=15, f=22
# 357. Expanding node with g=7, h=15, f=22
# 358. Expanding node with g=7, h=15, f=22
# 359. Expanding node with g=7, h=15, f=22
# 360. Expanding node with g=7, h=15, f=22
# 361. Expanding node with g=7, h=15, f=22
# 362. Expanding node with g=7, h=15, f=22
# 363. Expanding node with g=7, h=15, f=22
# 364. Expanding node with g=7, h=15, f=22
# 365. Expanding node with g=7, h=15, f=22
# 366. Expanding node with g=7, h=15, f=22
# 367. Expanding node with g=7, h=15, f=22
# 368. Expanding node with g=7, h=15, f=22
# 369. Expanding node with g=7, h=15, f=22
# 370. Expanding node with g=7, h=15, f=22
# 371. Expanding node with g=7, h=15, f=22
# 372. Expanding node with g=7, h=15, f=22
# 373. Expanding node with g=7, h=15, f=22
# 374. Expanding node with g=7, h=15, f=22
# 375. Expanding node with g=7, h=15, f=22
# 376. Expanding node with g=7, h=15, f=22
# 377. Expanding node with g=7, h=15, f=22
# 378. Expanding node with g=7, h=15, f=22
# 379. Expanding node with g=7, h=15, f=22
# 380. Expanding node with g=7, h=15, f=22
# 381. Expanding node with g=7, h=15, f=22
# 382. Expanding node with g=7, h=15, f=22
# 383. Expanding node with g=7, h=15, f=22
# 384. Expanding node with g=7, h=15, f=22
# 385. Expanding node with g=7, h=15, f=22
# 386. Expanding node with g=7, h=15, f=22
# 387. Expanding node with g=7, h=15, f=22
# 388. Expanding node with g=7, h=15, f=22
# 389. Expanding node with g=7, h=15, f=22
# 390. Expanding node with g=7, h=15, f=22
# 391. Expanding node with g=7, h=15, f=22
# 392. Expanding node with g=7, h=15, f=22
# 393. Expanding node with g=7, h=15, f=22
# 394. Expanding node with g=7, h=15, f=22
# 395. Expanding node with g=7, h=15, f=22
# 396. Expanding node with g=7, h=15, f=22
# 397. Expanding node with g=7, h=15, f=22
# 398. Expanding node with g=7, h=15, f=22
# 399. Expanding node with g=7, h=15, f=22
# 400. Expanding node with g=7, h=15, f=22
# 401. Expanding node with g=7, h=15, f=22
# 402. Expanding node with g=7, h=15, f=22
# 403. Expanding node with g=7, h=15, f=22
# 404. Expanding node with g=7, h=15, f=22
# 405. Expanding node with g=8, h=14, f=22
# 406. Expanding node with g=8, h=14, f=22
# 407. Expanding node with g=8, h=14, f=22
# 408. Expanding node with g=8, h=14, f=22
# 409. Expanding node with g=8, h=14, f=22
# 410. Expanding node with g=8, h=14, f=22
# 411. Expanding node with g=8, h=14, f=22
# 412. Expanding node with g=8, h=14, f=22
# 413. Expanding node with g=8, h=14, f=22
# 414. Expanding node with g=8, h=14, f=22
# 415. Expanding node with g=8, h=14, f=22
# 416. Expanding node with g=8, h=14, f=22
# 417. Expanding node with g=8, h=14, f=22
# 418. Expanding node with g=8, h=14, f=22
# 419. Expanding node with g=8, h=14, f=22
# 420. Expanding node with g=8, h=14, f=22
# 421. Expanding node with g=8, h=14, f=22
# 422. Expanding node with g=8, h=14, f=22
# 423. Expanding node with g=8, h=14, f=22
# 424. Expanding node with g=8, h=14, f=22
# 425. Expanding node with g=8, h=14, f=22
# 426. Expanding node with g=8, h=14, f=22
# 427. Expanding node with g=8, h=14, f=22
# 428. Expanding node with g=8, h=14, f=22
# 429. Expanding node with g=8, h=14, f=22
# 430. Expanding node with g=8, h=14, f=22
# 431. Expanding node with g=8, h=14, f=22
# 432. Expanding node with g=8, h=14, f=22
# 433. Expanding node with g=8, h=14, f=22
# 434. Expanding node with g=8, h=14, f=22
# 435. Expanding node with g=8, h=14, f=22
# 436. Expanding node with g=8, h=14, f=22
# 437. Expanding node with g=8, h=14, f=22
# 438. Expanding node with g=8, h=14, f=22
# 439. Expanding node with g=8, h=14, f=22
# 440. Expanding node with g=8, h=14, f=22
# 441. Expanding node with g=8, h=14, f=22
# 442. Expanding node with g=8, h=14, f=22
# 443. Expanding node with g=8, h=14, f=22
# 444. Expanding node with g=8, h=14, f=22
# 445. Expanding node with g=8, h=14, f=22
# 446. Expanding node with g=8, h=14, f=22
# 447. Expanding node with g=8, h=14, f=22
# 448. Expanding node with g=8, h=14, f=22
# 449. Expanding node with g=8, h=14, f=22
# 450. Expanding node with g=8, h=14, f=22
# 451. Expanding node with g=8, h=14, f=22
# 452. Expanding node with g=8, h=14, f=22
# 453. Expanding node with g=8, h=14, f=22
# 454. Expanding node with g=8, h=14, f=22
# 455. Expanding node with g=8, h=14, f=22
# 456. Expanding node with g=8, h=14, f=22
# 457. Expanding node with g=8, h=14, f=22
# 458. Expanding node with g=8, h=14, f=22
# 459. Expanding node with g=8, h=14, f=22
# 460. Expanding node with g=8, h=14, f=22
# 461. Expanding node with g=8, h=14, f=22
# 462. Expanding node with g=8, h=14, f=22
# 463. Expanding node with g=8, h=14, f=22
# 464. Expanding node with g=8, h=14, f=22
# 465. Expanding node with g=8, h=14, f=22
# 466. Expanding node with g=8, h=14, f=22
# 467. Expanding node with g=9, h=13, f=22
# 468. Expanding node with g=9, h=13, f=22
# 469. Expanding node with g=9, h=13, f=22
# 470. Expanding node with g=9, h=13, f=22
# 471. Expanding node with g=9, h=13, f=22
# 472. Expanding node with g=9, h=13, f=22
# 473. Expanding node with g=9, h=13, f=22
# 474. Expanding node with g=9, h=13, f=22
# 475. Expanding node with g=9, h=13, f=22
# 476. Expanding node with g=9, h=13, f=22
# 477. Expanding node with g=9, h=13, f=22
# 478. Expanding node with g=9, h=13, f=22
# 479. Expanding node with g=9, h=13, f=22
# 480. Expanding node with g=9, h=13, f=22
# 481. Expanding node with g=9, h=13, f=22
# 482. Expanding node with g=9, h=13, f=22
# 483. Expanding node with g=9, h=13, f=22
# 484. Expanding node with g=9, h=13, f=22
# 485. Expanding node with g=9, h=13, f=22
# 486. Expanding node with g=9, h=13, f=22
# 487. Expanding node with g=9, h=13, f=22
# 488. Expanding node with g=9, h=13, f=22
# 489. Expanding node with g=9, h=13, f=22
# 490. Expanding node with g=9, h=13, f=22
# 491. Expanding node with g=9, h=13, f=22
# 492. Expanding node with g=9, h=13, f=22
# 493. Expanding node with g=9, h=13, f=22
# 494. Expanding node with g=9, h=13, f=22
# 495. Expanding node with g=9, h=13, f=22
# 496. Expanding node with g=9, h=13, f=22
# 497. Expanding node with g=9, h=13, f=22
# 498. Expanding node with g=9, h=13, f=22
# 499. Expanding node with g=9, h=13, f=22
# 500. Expanding node with g=9, h=13, f=22
# 501. Expanding node with g=9, h=13, f=22
# 502. Expanding node with g=9, h=13, f=22
# 503. Expanding node with g=9, h=13, f=22
# 504. Expanding node with g=9, h=13, f=22
# 505. Expanding node with g=9, h=13, f=22
# 506. Expanding node with g=9, h=13, f=22
# 507. Expanding node with g=9, h=13, f=22
# 508. Expanding node with g=9, h=13, f=22
# 509. Expanding node with g=9, h=13, f=22
# 510. Expanding node with g=9, h=13, f=22
# 511. Expanding node with g=9, h=13, f=22
# 512. Expanding node with g=9, h=13, f=22
# 513. Expanding node with g=9, h=13, f=22
# 514. Expanding node with g=9, h=13, f=22
# 515. Expanding node with g=9, h=13, f=22
# 516. Expanding node with g=9, h=13, f=22
# 517. Expanding node with g=9, h=13, f=22
# 518. Expanding node with g=9, h=13, f=22
# 519. Expanding node with g=9, h=13, f=22
# 520. Expanding node with g=9, h=13, f=22
# 521. Expanding node with g=9, h=13, f=22
# 522. Expanding node with g=9, h=13, f=22
# 523. Expanding node with g=9, h=13, f=22
# 524. Expanding node with g=9, h=13, f=22
# 525. Expanding node with g=9, h=13, f=22
# 526. Expanding node with g=9, h=13, f=22
# 527. Expanding node with g=9, h=13, f=22
# 528. Expanding node with g=9, h=13, f=22
# 529. Expanding node with g=9, h=13, f=22
# 530. Expanding node with g=9, h=13, f=22
# 531. Expanding node with g=9, h=13, f=22
# 532. Expanding node with g=9, h=13, f=22
# 533. Expanding node with g=9, h=13, f=22
# 534. Expanding node with g=9, h=13, f=22
# 535. Expanding node with g=9, h=13, f=22
# 536. Expanding node with g=9, h=13, f=22
# 537. Expanding node with g=9, h=13, f=22
# 538. Expanding node with g=9, h=13, f=22
# 539. Expanding node with g=9, h=13, f=22
# 540. Expanding node with g=9, h=13, f=22
# 541. Expanding node with g=9, h=13, f=22
# 542. Expanding node with g=9, h=13, f=22
# 543. Expanding node with g=9, h=13, f=22
# 544. Expanding node with g=9, h=13, f=22
# 545. Expanding node with g=9, h=13, f=22
# 546. Expanding node with g=9, h=13, f=22
# 547. Expanding node with g=9, h=13, f=22
# 548. Expanding node with g=9, h=13, f=22
# 549. Expanding node with g=9, h=13, f=22
# 550. Expanding node with g=9, h=13, f=22
# 551. Expanding node with g=9, h=13, f=22
# 552. Expanding node with g=9, h=13, f=22
# 553. Expanding node with g=9, h=13, f=22
# 554. Expanding node with g=9, h=13, f=22
# 555. Expanding node with g=9, h=13, f=22
# 556. Expanding node with g=9, h=13, f=22
# 557. Expanding node with g=9, h=13, f=22
# 558. Expanding node with g=9, h=13, f=22
# 559. Expanding node with g=9, h=13, f=22
# 560. Expanding node with g=9, h=13, f=22
# 561. Expanding node with g=9, h=13, f=22
# 562. Expanding node with g=9, h=13, f=22
# 563. Expanding node with g=9, h=13, f=22
# 564. Expanding node with g=9, h=13, f=22
# 565. Expanding node with g=9, h=13, f=22
# 566. Expanding node with g=9, h=13, f=22
# 567. Expanding node with g=9, h=13, f=22
# 568. Expanding node with g=10, h=12, f=22
# 569. Expanding node with g=10, h=12, f=22
# 570. Expanding node with g=10, h=12, f=22
# 571. Expanding node with g=10, h=12, f=22
# 572. Expanding node with g=10, h=12, f=22
# 573. Expanding node with g=10, h=12, f=22
# 574. Expanding node with g=10, h=12, f=22
# 575. Expanding node with g=10, h=12, f=22
# 576. Expanding node with g=10, h=12, f=22
# 577. Expanding node with g=10, h=12, f=22
# 578. Expanding node with g=10, h=12, f=22
# 579. Expanding node with g=10, h=12, f=22
# 580. Expanding node with g=10, h=12, f=22
# 581. Expanding node with g=10, h=12, f=22
# 582. Expanding node with g=10, h=12, f=22
# 583. Expanding node with g=10, h=12, f=22
# 584. Expanding node with g=10, h=12, f=22
# 585. Expanding node with g=10, h=12, f=22
# 586. Expanding node with g=10, h=12, f=22
# 587. Expanding node with g=10, h=12, f=22
# 588. Expanding node with g=10, h=12, f=22
# 589. Expanding node with g=10, h=12, f=22
# 590. Expanding node with g=10, h=12, f=22
# 591. Expanding node with g=10, h=12, f=22
# 592. Expanding node with g=10, h=12, f=22
# 593. Expanding node with g=10, h=12, f=22
# 594. Expanding node with g=10, h=12, f=22
# 595. Expanding node with g=10, h=12, f=22
# 596. Expanding node with g=10, h=12, f=22
# 597. Expanding node with g=10, h=12, f=22
# 598. Expanding node with g=10, h=12, f=22
# 599. Expanding node with g=10, h=12, f=22
# 600. Expanding node with g=10, h=12, f=22
# 601. Expanding node with g=10, h=12, f=22
# 602. Expanding node with g=10, h=12, f=22
# 603. Expanding node with g=10, h=12, f=22
# 604. Expanding node with g=10, h=12, f=22
# 605. Expanding node with g=10, h=12, f=22
# 606. Expanding node with g=10, h=12, f=22
# 607. Expanding node with g=10, h=12, f=22
# 608. Expanding node with g=10, h=12, f=22
# 609. Expanding node with g=10, h=12, f=22
# 610. Expanding node with g=10, h=12, f=22
# 611. Expanding node with g=10, h=12, f=22
# 612. Expanding node with g=10, h=12, f=22
# 613. Expanding node with g=10, h=12, f=22
# 614. Expanding node with g=10, h=12, f=22
# 615. Expanding node with g=10, h=12, f=22
# 616. Expanding node with g=10, h=12, f=22
# 617. Expanding node with g=10, h=12, f=22
# 618. Expanding node with g=10, h=12, f=22
# 619. Expanding node with g=10, h=12, f=22
# 620. Expanding node with g=10, h=12, f=22
# 621. Expanding node with g=10, h=12, f=22
# 622. Expanding node with g=10, h=12, f=22
# 623. Expanding node with g=10, h=12, f=22
# 624. Expanding node with g=10, h=12, f=22
# 625. Expanding node with g=10, h=12, f=22
# 626. Expanding node with g=10, h=12, f=22
# 627. Expanding node with g=10, h=12, f=22
# 628. Expanding node with g=10, h=12, f=22
# 629. Expanding node with g=10, h=12, f=22
# 630. Expanding node with g=10, h=12, f=22
# 631. Expanding node with g=10, h=12, f=22
# 632. Expanding node with g=10, h=12, f=22
# 633. Expanding node with g=10, h=12, f=22
# 634. Expanding node with g=10, h=12, f=22
# 635. Expanding node with g=10, h=12, f=22
# 636. Expanding node with g=10, h=12, f=22
# 637. Expanding node with g=10, h=12, f=22
# 638. Expanding node with g=10, h=12, f=22
# 639. Expanding node with g=10, h=12, f=22
# 640. Expanding node with g=10, h=12, f=22
# 641. Expanding node with g=10, h=12, f=22
# 642. Expanding node with g=10, h=12, f=22
# 643. Expanding node with g=10, h=12, f=22
# 644. Expanding node with g=10, h=12, f=22
# 645. Expanding node with g=10, h=12, f=22
# 646. Expanding node with g=10, h=12, f=22
# 647. Expanding node with g=10, h=12, f=22
# 648. Expanding node with g=10, h=12, f=22
# 649. Expanding node with g=10, h=12, f=22
# 650. Expanding node with g=10, h=12, f=22
# 651. Expanding node with g=10, h=12, f=22
# 652. Expanding node with g=10, h=12, f=22
# 653. Expanding node with g=10, h=12, f=22
# 654. Expanding node with g=10, h=12, f=22
# 655. Expanding node with g=10, h=12, f=22
# 656. Expanding node with g=10, h=12, f=22
# 657. Expanding node with g=10, h=12, f=22
# 658. Expanding node with g=10, h=12, f=22
# 659. Expanding node with g=10, h=12, f=22
# 660. Expanding node with g=10, h=12, f=22
# 661. Expanding node with g=10, h=12, f=22
# 662. Expanding node with g=10, h=12, f=22
# 663. Expanding node with g=10, h=12, f=22
# 664. Expanding node with g=10, h=12, f=22
# 665. Expanding node with g=11, h=11, f=22
# 666. Expanding node with g=11, h=11, f=22
# 667. Expanding node with g=11, h=11, f=22
# 668. Expanding node with g=11, h=11, f=22
# 669. Expanding node with g=11, h=11, f=22
# 670. Expanding node with g=11, h=11, f=22
# 671. Expanding node with g=11, h=11, f=22
# 672. Expanding node with g=11, h=11, f=22
# 673. Expanding node with g=11, h=11, f=22
# 674. Expanding node with g=11, h=11, f=22
# 675. Expanding node with g=11, h=11, f=22
# 676. Expanding node with g=11, h=11, f=22
# 677. Expanding node with g=11, h=11, f=22
# 678. Expanding node with g=11, h=11, f=22
# 679. Expanding node with g=11, h=11, f=22
# 680. Expanding node with g=11, h=11, f=22
# 681. Expanding node with g=11, h=11, f=22
# 682. Expanding node with g=11, h=11, f=22
# 683. Expanding node with g=11, h=11, f=22
# 684. Expanding node with g=11, h=11, f=22
# 685. Expanding node with g=11, h=11, f=22
# 686. Expanding node with g=11, h=11, f=22
# 687. Expanding node with g=11, h=11, f=22
# 688. Expanding node with g=11, h=11, f=22
# 689. Expanding node with g=11, h=11, f=22
# 690. Expanding node with g=11, h=11, f=22
# 691. Expanding node with g=11, h=11, f=22
# 692. Expanding node with g=11, h=11, f=22
# 693. Expanding node with g=11, h=11, f=22
# 694. Expanding node with g=11, h=11, f=22
# 695. Expanding node with g=11, h=11, f=22
# 696. Expanding node with g=11, h=11, f=22
# 697. Expanding node with g=11, h=11, f=22
# 698. Expanding node with g=11, h=11, f=22
# 699. Expanding node with g=11, h=11, f=22
# 700. Expanding node with g=11, h=11, f=22
# 701. Expanding node with g=11, h=11, f=22
# 702. Expanding node with g=11, h=11, f=22
# 703. Expanding node with g=11, h=11, f=22
# 704. Expanding node with g=11, h=11, f=22
# 705. Expanding node with g=11, h=11, f=22
# 706. Expanding node with g=11, h=11, f=22
# 707. Expanding node with g=11, h=11, f=22
# 708. Expanding node with g=11, h=11, f=22
# 709. Expanding node with g=11, h=11, f=22
# 710. Expanding node with g=11, h=11, f=22
# 711. Expanding node with g=11, h=11, f=22
# 712. Expanding node with g=11, h=11, f=22
# 713. Expanding node with g=11, h=11, f=22
# 714. Expanding node with g=11, h=11, f=22
# 715. Expanding node with g=11, h=11, f=22
# 716. Expanding node with g=11, h=11, f=22
# 717. Expanding node with g=11, h=11, f=22
# 718. Expanding node with g=11, h=11, f=22
# 719. Expanding node with g=11, h=11, f=22
# 720. Expanding node with g=11, h=11, f=22
# 721. Expanding node with g=11, h=11, f=22
# 722. Expanding node with g=11, h=11, f=22
# 723. Expanding node with g=11, h=11, f=22
# 724. Expanding node with g=11, h=11, f=22
# 725. Expanding node with g=11, h=11, f=22
# 726. Expanding node with g=11, h=11, f=22
# 727. Expanding node with g=11, h=11, f=22
# 728. Expanding node with g=11, h=11, f=22
# 729. Expanding node with g=11, h=11, f=22
# 730. Expanding node with g=11, h=11, f=22
# 731. Expanding node with g=11, h=11, f=22
# 732. Expanding node with g=11, h=11, f=22
# 733. Expanding node with g=11, h=11, f=22
# 734. Expanding node with g=11, h=11, f=22
# 735. Expanding node with g=11, h=11, f=22
# 736. Expanding node with g=11, h=11, f=22
# 737. Expanding node with g=11, h=11, f=22
# 738. Expanding node with g=11, h=11, f=22
# 739. Expanding node with g=11, h=11, f=22
# 740. Expanding node with g=11, h=11, f=22
# 741. Expanding node with g=11, h=11, f=22
# 742. Expanding node with g=11, h=11, f=22
# 743. Expanding node with g=11, h=11, f=22
# 744. Expanding node with g=11, h=11, f=22
# 745. Expanding node with g=11, h=11, f=22
# 746. Expanding node with g=11, h=11, f=22
# 747. Expanding node with g=11, h=11, f=22
# 748. Expanding node with g=11, h=11, f=22
# 749. Expanding node with g=11, h=11, f=22
# 750. Expanding node with g=11, h=11, f=22
# 751. Expanding node with g=11, h=11, f=22
# 752. Expanding node with g=11, h=11, f=22
# 753. Expanding node with g=11, h=11, f=22
# 754. Expanding node with g=11, h=11, f=22
# 755. Expanding node with g=11, h=11, f=22
# 756. Expanding node with g=11, h=11, f=22
# 757. Expanding node with g=11, h=11, f=22
# 758. Expanding node with g=11, h=11, f=22
# 759. Expanding node with g=11, h=11, f=22
# 760. Expanding node with g=11, h=11, f=22
# 761. Expanding node with g=11, h=11, f=22
# 762. Expanding node with g=11, h=11, f=22
# 763. Expanding node with g=11, h=11, f=22
# 764. Expanding node with g=11, h=11, f=22
# 765. Expanding node with g=11, h=11, f=22
# 766. Expanding node with g=11, h=11, f=22
# 767. Expanding node with g=11, h=11, f=22
# 768. Expanding node with g=11, h=11, f=22
# 769. Expanding node with g=11, h=11, f=22
# 770. Expanding node with g=11, h=11, f=22
# 771. Expanding node with g=11, h=11, f=22
# 772. Expanding node with g=12, h=10, f=22
# 773. Expanding node with g=12, h=10, f=22
# 774. Expanding node with g=12, h=10, f=22
# 775. Expanding node with g=12, h=10, f=22
# 776. Expanding node with g=12, h=10, f=22
# 777. Expanding node with g=12, h=10, f=22
# 778. Expanding node with g=12, h=10, f=22
# 779. Expanding node with g=12, h=10, f=22
# 780. Expanding node with g=12, h=10, f=22
# 781. Expanding node with g=12, h=10, f=22
# 782. Expanding node with g=12, h=10, f=22
# 783. Expanding node with g=12, h=10, f=22
# 784. Expanding node with g=12, h=10, f=22
# 785. Expanding node with g=12, h=10, f=22
# 786. Expanding node with g=12, h=10, f=22
# 787. Expanding node with g=12, h=10, f=22
# 788. Expanding node with g=12, h=10, f=22
# 789. Expanding node with g=12, h=10, f=22
# 790. Expanding node with g=12, h=10, f=22
# 791. Expanding node with g=12, h=10, f=22
# 792. Expanding node with g=12, h=10, f=22
# 793. Expanding node with g=12, h=10, f=22
# 794. Expanding node with g=12, h=10, f=22
# 795. Expanding node with g=12, h=10, f=22
# 796. Expanding node with g=12, h=10, f=22
# 797. Expanding node with g=12, h=10, f=22
# 798. Expanding node with g=12, h=10, f=22
# 799. Expanding node with g=12, h=10, f=22
# 800. Expanding node with g=12, h=10, f=22
# 801. Expanding node with g=12, h=10, f=22
# 802. Expanding node with g=12, h=10, f=22
# 803. Expanding node with g=12, h=10, f=22
# 804. Expanding node with g=12, h=10, f=22
# 805. Expanding node with g=12, h=10, f=22
# 806. Expanding node with g=12, h=10, f=22
# 807. Expanding node with g=12, h=10, f=22
# 808. Expanding node with g=12, h=10, f=22
# 809. Expanding node with g=12, h=10, f=22
# 810. Expanding node with g=12, h=10, f=22
# 811. Expanding node with g=12, h=10, f=22
# 812. Expanding node with g=12, h=10, f=22
# 813. Expanding node with g=12, h=10, f=22
# 814. Expanding node with g=12, h=10, f=22
# 815. Expanding node with g=12, h=10, f=22
# 816. Expanding node with g=12, h=10, f=22
# 817. Expanding node with g=12, h=10, f=22
# 818. Expanding node with g=12, h=10, f=22
# 819. Expanding node with g=12, h=10, f=22
# 820. Expanding node with g=12, h=10, f=22
# 821. Expanding node with g=12, h=10, f=22
# 822. Expanding node with g=12, h=10, f=22
# 823. Expanding node with g=12, h=10, f=22
# 824. Expanding node with g=12, h=10, f=22
# 825. Expanding node with g=12, h=10, f=22
# 826. Expanding node with g=12, h=10, f=22
# 827. Expanding node with g=12, h=10, f=22
# 828. Expanding node with g=12, h=10, f=22
# 829. Expanding node with g=12, h=10, f=22
# 830. Expanding node with g=12, h=10, f=22
# 831. Expanding node with g=12, h=10, f=22
# 832. Expanding node with g=12, h=10, f=22
# 833. Expanding node with g=12, h=10, f=22
# 834. Expanding node with g=12, h=10, f=22
# 835. Expanding node with g=12, h=10, f=22
# 836. Expanding node with g=12, h=10, f=22
# 837. Expanding node with g=12, h=10, f=22
# 838. Expanding node with g=12, h=10, f=22
# 839. Expanding node with g=12, h=10, f=22
# 840. Expanding node with g=12, h=10, f=22
# 841. Expanding node with g=12, h=10, f=22
# 842. Expanding node with g=12, h=10, f=22
# 843. Expanding node with g=12, h=10, f=22
# 844. Expanding node with g=12, h=10, f=22
# 845. Expanding node with g=12, h=10, f=22
# 846. Expanding node with g=12, h=10, f=22
# 847. Expanding node with g=12, h=10, f=22
# 848. Expanding node with g=12, h=10, f=22
# 849. Expanding node with g=12, h=10, f=22
# 850. Expanding node with g=12, h=10, f=22
# 851. Expanding node with g=12, h=10, f=22
# 852. Expanding node with g=12, h=10, f=22
# 853. Expanding node with g=12, h=10, f=22
# 854. Expanding node with g=12, h=10, f=22
# 855. Expanding node with g=12, h=10, f=22
# 856. Expanding node with g=12, h=10, f=22
# 857. Expanding node with g=12, h=10, f=22
# 858. Expanding node with g=12, h=10, f=22
# 859. Expanding node with g=12, h=10, f=22
# 860. Expanding node with g=12, h=10, f=22
# 861. Expanding node with g=12, h=10, f=22
# 862. Expanding node with g=12, h=10, f=22
# 863. Expanding node with g=12, h=10, f=22
# 864. Expanding node with g=12, h=10, f=22
# 865. Expanding node with g=12, h=10, f=22
# 866. Expanding node with g=12, h=10, f=22
# 867. Expanding node with g=12, h=10, f=22
# 868. Expanding node with g=12, h=10, f=22
# 869. Expanding node with g=13, h=9, f=22
# 870. Expanding node with g=13, h=9, f=22
# 871. Expanding node with g=13, h=9, f=22
# 872. Expanding node with g=13, h=9, f=22
# 873. Expanding node with g=13, h=9, f=22
# 874. Expanding node with g=13, h=9, f=22
# 875. Expanding node with g=13, h=9, f=22
# 876. Expanding node with g=13, h=9, f=22
# 877. Expanding node with g=13, h=9, f=22
# 878. Expanding node with g=13, h=9, f=22
# 879. Expanding node with g=13, h=9, f=22
# 880. Expanding node with g=13, h=9, f=22
# 881. Expanding node with g=13, h=9, f=22
# 882. Expanding node with g=13, h=9, f=22
# 883. Expanding node with g=13, h=9, f=22
# 884. Expanding node with g=13, h=9, f=22
# 885. Expanding node with g=13, h=9, f=22
# 886. Expanding node with g=13, h=9, f=22
# 887. Expanding node with g=13, h=9, f=22
# 888. Expanding node with g=13, h=9, f=22
# 889. Expanding node with g=13, h=9, f=22
# 890. Expanding node with g=13, h=9, f=22
# 891. Expanding node with g=13, h=9, f=22
# 892. Expanding node with g=13, h=9, f=22
# 893. Expanding node with g=13, h=9, f=22
# 894. Expanding node with g=13, h=9, f=22
# 895. Expanding node with g=13, h=9, f=22
# 896. Expanding node with g=13, h=9, f=22
# 897. Expanding node with g=13, h=9, f=22
# 898. Expanding node with g=13, h=9, f=22
# 899. Expanding node with g=13, h=9, f=22
# 900. Expanding node with g=13, h=9, f=22
# 901. Expanding node with g=13, h=9, f=22
# 902. Expanding node with g=13, h=9, f=22
# 903. Expanding node with g=13, h=9, f=22
# 904. Expanding node with g=13, h=9, f=22
# 905. Expanding node with g=13, h=9, f=22
# 906. Expanding node with g=13, h=9, f=22
# 907. Expanding node with g=13, h=9, f=22
# 908. Expanding node with g=13, h=9, f=22
# 909. Expanding node with g=13, h=9, f=22
# 910. Expanding node with g=13, h=9, f=22
# 911. Expanding node with g=13, h=9, f=22
# 912. Expanding node with g=13, h=9, f=22
# 913. Expanding node with g=13, h=9, f=22
# 914. Expanding node with g=13, h=9, f=22
# 915. Expanding node with g=13, h=9, f=22
# 916. Expanding node with g=13, h=9, f=22
# 917. Expanding node with g=13, h=9, f=22
# 918. Expanding node with g=13, h=9, f=22
# 919. Expanding node with g=13, h=9, f=22
# 920. Expanding node with g=13, h=9, f=22
# 921. Expanding node with g=13, h=9, f=22
# 922. Expanding node with g=13, h=9, f=22
# 923. Expanding node with g=13, h=9, f=22
# 924. Expanding node with g=13, h=9, f=22
# 925. Expanding node with g=13, h=9, f=22
# 926. Expanding node with g=13, h=9, f=22
# 927. Expanding node with g=13, h=9, f=22
# 928. Expanding node with g=13, h=9, f=22
# 929. Expanding node with g=13, h=9, f=22
# 930. Expanding node with g=13, h=9, f=22
# 931. Expanding node with g=13, h=9, f=22
# 932. Expanding node with g=13, h=9, f=22
# 933. Expanding node with g=13, h=9, f=22
# 934. Expanding node with g=13, h=9, f=22
# 935. Expanding node with g=13, h=9, f=22
# 936. Expanding node with g=13, h=9, f=22
# 937. Expanding node with g=13, h=9, f=22
# 938. Expanding node with g=13, h=9, f=22
# 939. Expanding node with g=13, h=9, f=22
# 940. Expanding node with g=13, h=9, f=22
# 941. Expanding node with g=13, h=9, f=22
# 942. Expanding node with g=13, h=9, f=22
# 943. Expanding node with g=13, h=9, f=22
# 944. Expanding node with g=13, h=9, f=22
# 945. Expanding node with g=13, h=9, f=22
# 946. Expanding node with g=13, h=9, f=22
# 947. Expanding node with g=13, h=9, f=22
# 948. Expanding node with g=13, h=9, f=22
# 949. Expanding node with g=13, h=9, f=22
# 950. Expanding node with g=13, h=9, f=22
# 951. Expanding node with g=13, h=9, f=22
# 952. Expanding node with g=13, h=9, f=22
# 953. Expanding node with g=13, h=9, f=22
# 954. Expanding node with g=13, h=9, f=22
# 955. Expanding node with g=13, h=9, f=22
# 956. Expanding node with g=13, h=9, f=22
# 957. Expanding node with g=13, h=9, f=22
# 958. Expanding node with g=13, h=9, f=22
# 959. Expanding node with g=13, h=9, f=22
# 960. Expanding node with g=13, h=9, f=22
# 961. Expanding node with g=13, h=9, f=22
# 962. Expanding node with g=13, h=9, f=22
# 963. Expanding node with g=13, h=9, f=22
# 964. Expanding node with g=13, h=9, f=22
# 965. Expanding node with g=13, h=9, f=22
# 966. Expanding node with g=13, h=9, f=22
# 967. Expanding node with g=14, h=8, f=22
# 968. Expanding node with g=14, h=8, f=22
# 969. Expanding node with g=14, h=8, f=22
# 970. Expanding node with g=14, h=8, f=22
# 971. Expanding node with g=14, h=8, f=22
# 972. Expanding node with g=14, h=8, f=22
# 973. Expanding node with g=14, h=8, f=22
# 974. Expanding node with g=14, h=8, f=22
# 975. Expanding node with g=14, h=8, f=22
# 976. Expanding node with g=14, h=8, f=22
# 977. Expanding node with g=14, h=8, f=22
# 978. Expanding node with g=14, h=8, f=22
# 979. Expanding node with g=14, h=8, f=22
# 980. Expanding node with g=14, h=8, f=22
# 981. Expanding node with g=14, h=8, f=22
# 982. Expanding node with g=14, h=8, f=22
# 983. Expanding node with g=14, h=8, f=22
# 984. Expanding node with g=14, h=8, f=22
# 985. Expanding node with g=14, h=8, f=22
# 986. Expanding node with g=14, h=8, f=22
# 987. Expanding node with g=14, h=8, f=22
# 988. Expanding node with g=14, h=8, f=22
# 989. Expanding node with g=14, h=8, f=22
# 990. Expanding node with g=14, h=8, f=22
# 991. Expanding node with g=14, h=8, f=22
# 992. Expanding node with g=14, h=8, f=22
# 993. Expanding node with g=14, h=8, f=22
# 994. Expanding node with g=14, h=8, f=22
# 995. Expanding node with g=14, h=8, f=22
# 996. Expanding node with g=14, h=8, f=22
# 997. Expanding node with g=14, h=8, f=22
# 998. Expanding node with g=14, h=8, f=22
# 999. Expanding node with g=14, h=8, f=22
# 1000. Expanding node with g=14, h=8, f=22
# 1001. Expanding node with g=14, h=8, f=22
# 1002. Expanding node with g=14, h=8, f=22
# 1003. Expanding node with g=14, h=8, f=22
# 1004. Expanding node with g=14, h=8, f=22
# 1005. Expanding node with g=14, h=8, f=22
# 1006. Expanding node with g=14, h=8, f=22
# 1007. Expanding node with g=14, h=8, f=22
# 1008. Expanding node with g=14, h=8, f=22
# 1009. Expanding node with g=14, h=8, f=22
# 1010. Expanding node with g=14, h=8, f=22
# 1011. Expanding node with g=14, h=8, f=22
# 1012. Expanding node with g=14, h=8, f=22
# 1013. Expanding node with g=14, h=8, f=22
# 1014. Expanding node with g=14, h=8, f=22
# 1015. Expanding node with g=14, h=8, f=22
# 1016. Expanding node with g=14, h=8, f=22
# 1017. Expanding node with g=14, h=8, f=22
# 1018. Expanding node with g=14, h=8, f=22
# 1019. Expanding node with g=14, h=8, f=22
# 1020. Expanding node with g=14, h=8, f=22
# 1021. Expanding node with g=14, h=8, f=22
# 1022. Expanding node with g=14, h=8, f=22
# 1023. Expanding node with g=14, h=8, f=22
# 1024. Expanding node with g=14, h=8, f=22
# 1025. Expanding node with g=14, h=8, f=22
# 1026. Expanding node with g=14, h=8, f=22
# 1027. Expanding node with g=15, h=7, f=22
# 1028. Expanding node with g=15, h=7, f=22
# 1029. Expanding node with g=15, h=7, f=22
# 1030. Expanding node with g=15, h=7, f=22
# 1031. Expanding node with g=15, h=7, f=22
# 1032. Expanding node with g=15, h=7, f=22
# 1033. Expanding node with g=15, h=7, f=22
# 1034. Expanding node with g=15, h=7, f=22
# 1035. Expanding node with g=15, h=7, f=22
# 1036. Expanding node with g=15, h=7, f=22
# 1037. Expanding node with g=15, h=7, f=22
# 1038. Expanding node with g=15, h=7, f=22
# 1039. Expanding node with g=15, h=7, f=22
# 1040. Expanding node with g=15, h=7, f=22
# 1041. Expanding node with g=15, h=7, f=22
# 1042. Expanding node with g=15, h=7, f=22
# 1043. Expanding node with g=15, h=7, f=22
# 1044. Expanding node with g=15, h=7, f=22
# 1045. Expanding node with g=15, h=7, f=22
# 1046. Expanding node with g=15, h=7, f=22
# 1047. Expanding node with g=15, h=7, f=22
# 1048. Expanding node with g=15, h=7, f=22
# 1049. Expanding node with g=15, h=7, f=22
# 1050. Expanding node with g=15, h=7, f=22
# 1051. Expanding node with g=15, h=7, f=22
# 1052. Expanding node with g=15, h=7, f=22
# 1053. Expanding node with g=15, h=7, f=22
# 1054. Expanding node with g=15, h=7, f=22
# 1055. Expanding node with g=15, h=7, f=22
# 1056. Expanding node with g=15, h=7, f=22
# 1057. Expanding node with g=15, h=7, f=22
# 1058. Expanding node with g=15, h=7, f=22
# 1059. Expanding node with g=15, h=7, f=22
# 1060. Expanding node with g=15, h=7, f=22
# 1061. Expanding node with g=15, h=7, f=22
# 1062. Expanding node with g=15, h=7, f=22
# 1063. Expanding node with g=15, h=7, f=22
# 1064. Expanding node with g=15, h=7, f=22
# 1065. Expanding node with g=15, h=7, f=22
# 1066. Expanding node with g=15, h=7, f=22
# 1067. Expanding node with g=15, h=7, f=22
# 1068. Expanding node with g=15, h=7, f=22
# 1069. Expanding node with g=15, h=7, f=22
# 1070. Expanding node with g=15, h=7, f=22
# 1071. Expanding node with g=15, h=7, f=22
# 1072. Expanding node with g=15, h=7, f=22
# 1073. Expanding node with g=15, h=7, f=22
# 1074. Expanding node with g=16, h=6, f=22
# 1075. Expanding node with g=16, h=6, f=22
# 1076. Expanding node with g=16, h=6, f=22
# 1077. Expanding node with g=16, h=6, f=22
# 1078. Expanding node with g=16, h=6, f=22
# 1079. Expanding node with g=16, h=6, f=22
# 1080. Expanding node with g=16, h=6, f=22
# 1081. Expanding node with g=16, h=6, f=22
# 1082. Expanding node with g=16, h=6, f=22
# 1083. Expanding node with g=16, h=6, f=22
# 1084. Expanding node with g=16, h=6, f=22
# 1085. Expanding node with g=16, h=6, f=22
# 1086. Expanding node with g=16, h=6, f=22
# 1087. Expanding node with g=16, h=6, f=22
# 1088. Expanding node with g=16, h=6, f=22
# 1089. Expanding node with g=16, h=6, f=22
# 1090. Expanding node with g=16, h=6, f=22
# 1091. Expanding node with g=16, h=6, f=22
# 1092. Expanding node with g=16, h=6, f=22
# 1093. Expanding node with g=16, h=6, f=22
# 1094. Expanding node with g=16, h=6, f=22
# 1095. Expanding node with g=16, h=6, f=22
# 1096. Expanding node with g=16, h=6, f=22
# 1097. Expanding node with g=16, h=6, f=22
# 1098. Expanding node with g=16, h=6, f=22
# 1099. Expanding node with g=16, h=6, f=22
# 1100. Expanding node with g=16, h=6, f=22
# 1101. Expanding node with g=16, h=6, f=22
# 1102. Expanding node with g=16, h=6, f=22
# 1103. Expanding node with g=16, h=6, f=22
# 1104. Expanding node with g=16, h=6, f=22
# 1105. Expanding node with g=16, h=6, f=22
# 1106. Expanding node with g=16, h=6, f=22
# 1107. Expanding node with g=16, h=6, f=22
# 1108. Expanding node with g=16, h=6, f=22
# 1109. Expanding node with g=16, h=6, f=22
# 1110. Expanding node with g=16, h=6, f=22
# 1111. Expanding node with g=16, h=6, f=22
# 1112. Expanding node with g=17, h=5, f=22
# 1113. Expanding node with g=17, h=5, f=22
# 1114. Expanding node with g=17, h=5, f=22
# 1115. Expanding node with g=17, h=5, f=22
# 1116. Expanding node with g=17, h=5, f=22
# 1117. Expanding node with g=17, h=5, f=22
# 1118. Expanding node with g=17, h=5, f=22
# 1119. Expanding node with g=17, h=5, f=22
# 1120. Expanding node with g=17, h=5, f=22
# 1121. Expanding node with g=17, h=5, f=22
# 1122. Expanding node with g=17, h=5, f=22
# 1123. Expanding node with g=17, h=5, f=22
# 1124. Expanding node with g=17, h=5, f=22
# 1125. Expanding node with g=17, h=5, f=22
# 1126. Expanding node with g=17, h=5, f=22
# 1127. Expanding node with g=17, h=5, f=22
# 1128. Expanding node with g=17, h=5, f=22
# 1129. Expanding node with g=17, h=5, f=22
# 1130. Expanding node with g=17, h=5, f=22
# 1131. Expanding node with g=17, h=5, f=22
# 1132. Expanding node with g=17, h=5, f=22
# 1133. Expanding node with g=17, h=5, f=22
# 1134. Expanding node with g=17, h=5, f=22
# 1135. Expanding node with g=17, h=5, f=22
# 1136. Expanding node with g=17, h=5, f=22
# 1137. Expanding node with g=17, h=5, f=22
# 1138. Expanding node with g=17, h=5, f=22
# 1139. Expanding node with g=17, h=5, f=22
# 1140. Expanding node with g=17, h=5, f=22
# 1141. Expanding node with g=17, h=5, f=22
# 1142. Expanding node with g=17, h=5, f=22
# 1143. Expanding node with g=18, h=4, f=22
# 1144. Expanding node with g=18, h=4, f=22
# 1145. Expanding node with g=18, h=4, f=22
# 1146. Expanding node with g=18, h=4, f=22
# 1147. Expanding node with g=18, h=4, f=22
# 1148. Expanding node with g=18, h=4, f=22
# 1149. Expanding node with g=18, h=4, f=22
# 1150. Expanding node with g=18, h=4, f=22
# 1151. Expanding node with g=18, h=4, f=22
# 1152. Expanding node with g=18, h=4, f=22
# 1153. Expanding node with g=18, h=4, f=22
# 1154. Expanding node with g=18, h=4, f=22
# 1155. Expanding node with g=18, h=4, f=22
# 1156. Expanding node with g=18, h=4, f=22
# 1157. Expanding node with g=18, h=4, f=22
# 1158. Expanding node with g=18, h=4, f=22
# 1159. Expanding node with g=18, h=4, f=22
# 1160. Expanding node with g=18, h=4, f=22
# 1161. Expanding node with g=19, h=3, f=22
# 1162. Expanding node with g=20, h=2, f=22
# 1163. Expanding node with g=21, h=1, f=22
# 1164. Expanding node with g=22, h=0, f=22
#
# Solution found in 22 moves:
# Step 0:
# [4, 5, 8]
# [3, 1, 0]
# [7, 6, 2]
#
# Step 1:
# [4, 5, 0]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 2:
# [4, 0, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 3:
# [0, 4, 5]
# [3, 1, 8]
# [7, 6, 2]
#
# Step 4:
# [3, 4, 5]
# [0, 1, 8]
# [7, 6, 2]
#
# Step 5:
# [3, 4, 5]
# [1, 0, 8]
# [7, 6, 2]
#
# Step 6:
# [3, 0, 5]
# [1, 4, 8]
# [7, 6, 2]
#
# Step 7:
# [3, 5, 0]
# [1, 4, 8]
# [7, 6, 2]
#
# Step 8:
# [3, 5, 8]
# [1, 4, 0]
# [7, 6, 2]
#
# Step 9:
# [3, 5, 8]
# [1, 4, 2]
# [7, 6, 0]
#
# Step 10:
# [3, 5, 8]
# [1, 4, 2]
# [7, 0, 6]
#
# Step 11:
# [3, 5, 8]
# [1, 0, 2]
# [7, 4, 6]
#
# Step 12:
# [3, 0, 8]
# [1, 5, 2]
# [7, 4, 6]
#
# Step 13:
# [0, 3, 8]
# [1, 5, 2]
# [7, 4, 6]
#
# Step 14:
# [1, 3, 8]
# [0, 5, 2]
# [7, 4, 6]
#
# Step 15:
# [1, 3, 8]
# [7, 5, 2]
# [0, 4, 6]
#
# Step 16:
# [1, 3, 8]
# [7, 5, 2]
# [4, 0, 6]
#
# Step 17:
# [1, 3, 8]
# [7, 0, 2]
# [4, 5, 6]
#
# Step 18:
# [1, 3, 8]
# [7, 2, 0]
# [4, 5, 6]
#
# Step 19:
# [1, 3, 0]
# [7, 2, 8]
# [4, 5, 6]
#
# Step 20:
# [1, 0, 3]
# [7, 2, 8]
# [4, 5, 6]
#
# Step 21:
# [1, 2, 3]
# [7, 0, 8]
# [4, 5, 6]
#
# Step 22:
# [1, 2, 3]
# [7, 8, 0]
# [4, 5, 6]
